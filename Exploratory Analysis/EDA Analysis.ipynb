# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import folium
import geopy

from sklearn import preprocessing, cluster
from sklearn.cluster import KMeans
import scipy

import minisom

# %% [markdown]
# # Reading the file

# %%
Geolocational_exploratory_data=pd.read_csv('food_coded.csv')
Geolocational_exploratory_data.head(10)
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
# 5   2.25       1          1               610           3.0           980.0
# 6    3.8       2          1               610           3.0           420.0
# 7    3.3       1          1               720           3.0           420.0
# 8    3.3       1          1               430           NaN           420.0
# 9    3.3       1          1               430           3.0           315.0
#
#    coffee                                  comfort_food  \
# 0       1                                          none
# 1       2                   chocolate, chips, ice cream
# 2       2               frozen yogurt, pizza, fast food
# 3       2              Pizza, Mac and cheese, ice cream
# 4       2                  Ice cream, chocolate, chips
# 5       2                     Candy, brownies and soda.
# 6       2  Chocolate, ice cream, french fries, pretzels
# 7       1              Ice cream, cheeseburgers, chips.
# 8       1                      Donuts, ice cream, chips
# 9       2         Mac and cheese, chocolate, and pasta
#
#                                 comfort_food_reasons  \
# 0                              we dont have comfort
# 1                               Stress, bored, anger
# 2                                    stress, sadness
# 3                                            Boredom
# 4                         Stress, boredom, cravings
# 5  None, i don't eat comfort food. I just eat whe...
# 6                                    stress, boredom
# 7  I eat comfort food when im stressed out from s...
# 8                                           Boredom
# 9                         Stress, anger and sadness
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
# 5                         4.0  ...   1.0     2.0          4             940.0
# 6                         1.0  ...   1.0     1.0          5             940.0
# 7                         1.0  ...   1.0     2.0          1             725.0
# 8                         2.0  ...   2.0     2.0          5             725.0
# 9                         1.0  ...   1.0     1.0          4             580.0
#
#    turkey_calories   type_sports veggies_day  vitamins  waffle_calories  \
# 0              345    car racing           5         1             1315
# 1              690   Basketball            4         2              900
# 2              500          none           5         1              900
# 3              690           NaN           3         1             1315
# 4              500      Softball           4         2              760
# 5              345         None.           1         2             1315
# 6              690        soccer           4         1             1315
# 7              500          none           4         2             1315
# 8              345          none           3         2              760
# 9              345  field hockey           5         1              900
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
# 5                       190
# 6                       180
# 7                       137
# 8                       180
# 9                       125
#
# [10 rows x 61 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The process of Extracting the features, (and dealing with different kinds of values as well as NaN values) is known as Data Cleaning.
#
# First, we will check the columns that have missing values, and the number of missing values in each column

# %%
Geolocational_exploratory_data.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
#        'persian_food', 'self_perception_weight', 'soup', 'sports', 'thai_food',
#        'tortilla_calories', 'turkey_calories', 'type_sports', 'veggies_day',
#        'vitamins', 'waffle_calories', 'weight'],
#       dtype='object')

# %%
missing_val_cols=[]
for col in Geolocational_exploratory_data.columns:
    if Geolocational_exploratory_data[col].isnull().any():
        missing_val_cols.append(col)

# %%
for i in missing_val_cols:
    print(i , Geolocational_exploratory_data[i].isnull().sum())
# Out:
# GPA 2
# calories_day 19
# calories_scone 1
# comfort_food 1
# comfort_food_reasons 1
# comfort_food_reasons_coded 19
# cook 3
# cuisine 17
# diet_current 1
# drink 2
# eating_changes 3
# employment 9
# exercise 13
# father_education 1
# father_profession 3
# fav_cuisine 2
# fav_food 2
# food_childhood 1
# healthy_meal 1
# ideal_diet 1
# income 1
# life_rewarding 1
# marital_status 1
# meals_dinner_friend 3
# mother_education 3
# mother_profession 2
# on_off_campus 1
# persian_food 1
# self_perception_weight 1
# soup 1
# sports 2
# tortilla_calories 1
# type_sports 21
# weight 2

# %%
column=['cook','eating_out','employment','ethnic_food', 'exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day']

# %%
data=Geolocational_exploratory_data[column]
data
# Out:
#      cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0     2.0           3         3.0            1       1.0          5     5.0
# 1     3.0           2         2.0            4       1.0          4     4.0
# 2     1.0           2         3.0            5       2.0          5     6.0
# 3     2.0           2         3.0            5       3.0          4     6.0
# 4     1.0           2         2.0            4       1.0          4     6.0
# ..    ...         ...         ...          ...       ...        ...     ...
# 120   3.0           2         1.0            4       2.0          5     4.0
# 121   3.0           4         3.0            3       2.0          4     2.0
# 122   3.0           3         3.0            5       2.0          4     2.0
# 123   3.0           5         2.0            2       1.0          5     4.0
# 124   NaN           1         2.0            3       2.0          3     5.0
#
#      on_off_campus  pay_meal_out  sports  veggies_day
# 0              1.0             2     1.0            5
# 1              1.0             4     1.0            4
# 2              2.0             3     2.0            5
# 3              1.0             2     2.0            3
# 4              1.0             4     1.0            4
# ..             ...           ...     ...          ...
# 120            3.0             4     1.0            5
# 121            1.0             4     NaN            5
# 122            1.0             4     2.0            4
# 123            1.0             3     2.0            3
# 124            1.0             3     2.0            4
#
# [125 rows x 11 columns]

# %%
Geolocational_exploratory_data.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# min      1.00000                    1.000000    1.000000
# 25%      2.00000                    2.000000    2.000000
# 50%      2.00000                    2.000000    3.000000
# 75%      2.00000                    3.000000    3.000000
# max      2.00000                    9.000000    5.000000
#
#        comfort_food_reasons_coded.1     cuisine  ...  persian_food  \
# count                    125.000000  108.000000  ...    124.000000
# mean                       2.688000    1.388889  ...      2.806452
# std                        1.910987    0.974759  ...      1.423824
# min                        1.000000    1.000000  ...      1.000000
# 25%                        2.000000    1.000000  ...      2.000000
# 50%                        2.000000    1.000000  ...      3.000000
# 75%                        3.000000    1.000000  ...      4.000000
# max                        9.000000    6.000000  ...      5.000000
#
#        self_perception_weight        soup      sports   thai_food  \
# count              124.000000  124.000000  123.000000  125.000000
# mean                 3.120968    1.217742    1.390244    3.336000
# std                  1.115980    0.414385    0.489800    1.436528
# min                  1.000000    1.000000    1.000000    1.000000
# 25%                  2.000000    1.000000    1.000000    2.000000
# 50%                  3.000000    1.000000    1.000000    3.000000
# 75%                  4.000000    1.000000    2.000000    5.000000
# max                  6.000000    2.000000    2.000000    5.000000
#
#        tortilla_calories  turkey_calories  veggies_day    vitamins  \
# count         124.000000       125.000000   125.000000  125.000000
# mean          947.580645       555.040000     4.008000    1.512000
# std           202.090179       152.370379     1.081337    0.501867
# min           580.000000       345.000000     1.000000    1.000000
# 25%           725.000000       500.000000     3.000000    1.000000
# 50%           940.000000       500.000000     4.000000    2.000000
# 75%          1165.000000       690.000000     5.000000    2.000000
# max          1165.000000       850.000000     5.000000    2.000000
#
#        waffle_calories
# count       125.000000
# mean       1073.400000
# std         248.667092
# min         575.000000
# 25%         900.000000
# 50%         900.000000
# 75%        1315.000000
# max        1315.000000
#
# [8 rows x 47 columns]

# %% [markdown]
# We can now replace the missing values using the fillna() function. We filter down the columns with lots of missing values and manually replace them with values which is more relevant.

# %%
Geolocational_exploratory_data['calories_day'].fillna(1,inplace=True)                
Geolocational_exploratory_data['comfort_food_reasons_coded'].fillna(9,inplace=True) 
Geolocational_exploratory_data['cuisine'].fillna(6,inplace=True)                     
Geolocational_exploratory_data['employment'].fillna(4,inplace=True)                  
Geolocational_exploratory_data['exercise'].fillna(5,inplace=True)                   
Geolocational_exploratory_data['type_sports'].fillna('Nothing',inplace=True)

# %% [markdown]
# We will now remove all the columns which are not useful for our objective. We keep the following columns:
#
# 'Gender', 'breakfast', 'cook', 'cuisine', 'employment', 'exercise', 'fav_food', 'grade_level', 'income', 'marital_status', 'on_off_campus', 'pay_meal_out'

# %%
req_cols = ['Gender', 'breakfast', 'cook', 'cuisine',
            'eating_out', 'employment', 'exercise',
            'fav_food', 'grade_level', 'income',
            'marital_status', 'on_off_campus', 'pay_meal_out', ]

# %%
Geolocational_exploratory_data2= Geolocational_exploratory_data[req_cols]
Geolocational_exploratory_data2.head()
# Out:
#    Gender  breakfast  cook  cuisine  eating_out  employment  exercise  \
# 0       2          1   2.0      6.0           3         3.0       1.0
# 1       1          1   3.0      1.0           2         2.0       1.0
# 2       1          1   1.0      3.0           2         3.0       2.0
# 3       1          1   2.0      2.0           2         3.0       3.0
# 4       1          1   1.0      2.0           2         2.0       1.0
#
#    fav_food  grade_level  income  marital_status  on_off_campus  pay_meal_out
# 0       1.0            2     5.0             1.0            1.0             2
# 1       1.0            4     4.0             2.0            1.0             4
# 2       3.0            3     6.0             2.0            2.0             3
# 3       1.0            4     6.0             2.0            1.0             2
# 4       3.0            4     6.0             1.0            1.0             4

# %%
full_dataset=pd.read_csv("food_coded.csv");
print(full_dataset.head())
print(full_dataset.info())
#print(full_dataset.describe())
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
#    comfort_food_reasons_coded  ...  soup  sports  thai_food tortilla_calories  \
# 0                         9.0  ...   1.0     1.0          1            1165.0
# 1                         1.0  ...   1.0     1.0          2             725.0
# 2                         1.0  ...   1.0     2.0          5            1165.0
# 3                         2.0  ...   1.0     2.0          5             725.0
# 4                         1.0  ...   1.0     1.0          4             940.0
#
#    turkey_calories  type_sports veggies_day  vitamins  waffle_calories  \
# 0              345   car racing           5         1             1315
# 1              690  Basketball            4         2              900
# 2              500         none           5         1              900
# 3              690          NaN           3         1             1315
# 4              500     Softball           4         2              760
#
#                      weight
# 0                       187
# 1                       155
# 2  I'm not answering this.
# 3             Not sure, 240
# 4                       190
#
# [5 rows x 61 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
#  12  cuisine                       108 non-null    float64
#  13  diet_current                  124 non-null    object
#  14  diet_current_coded            125 non-null    int64
#  15  drink                         123 non-null    float64
#  16  eating_changes                122 non-null    object
#  17  eating_changes_coded          125 non-null    int64
#  18  eating_changes_coded1         125 non-null    int64
#  19  eating_out                    125 non-null    int64
#  20  employment                    116 non-null    float64
#  21  ethnic_food                   125 non-null    int64
#  22  exercise                      112 non-null    float64
#  23  father_education              124 non-null    float64
#  24  father_profession             122 non-null    object
#  25  fav_cuisine                   123 non-null    object
#  26  fav_cuisine_coded             125 non-null    int64
#  27  fav_food                      123 non-null    float64
#  28  food_childhood                124 non-null    object
#  29  fries                         125 non-null    int64
#  30  fruit_day                     125 non-null    int64
#  31  grade_level                   125 non-null    int64
#  32  greek_food                    125 non-null    int64
#  33  healthy_feeling               125 non-null    int64
#  34  healthy_meal                  124 non-null    object
#  35  ideal_diet                    124 non-null    object
#  36  ideal_diet_coded              125 non-null    int64
#  37  income                        124 non-null    float64
#  38  indian_food                   125 non-null    int64
#  39  italian_food                  125 non-null    int64
#  40  life_rewarding                124 non-null    float64
#  41  marital_status                124 non-null    float64
#  42  meals_dinner_friend           122 non-null    object
#  43  mother_education              122 non-null    float64
#  44  mother_profession             123 non-null    object
#  45  nutritional_check             125 non-null    int64
#  46  on_off_campus                 124 non-null    float64
#  47  parents_cook                  125 non-null    int64
#  48  pay_meal_out                  125 non-null    int64
#  49  persian_food                  124 non-null    float64
#  50  self_perception_weight        124 non-null    float64
#  51  soup                          124 non-null    float64
#  52  sports                        123 non-null    float64
#  53  thai_food                     125 non-null    int64
#  54  tortilla_calories             124 non-null    float64
#  55  turkey_calories               125 non-null    int64
#  56  type_sports                   104 non-null    object
#  57  veggies_day                   125 non-null    int64
#  58  vitamins                      125 non-null    int64
#  59  waffle_calories               125 non-null    int64
#  60  weight                        123 non-null    object
# dtypes: float64(20), int64(27), object(14)
# memory usage: 59.7+ KB
# None

# %% [markdown]
# We try to retrieve all the missing values from the below specified columns.

# %%
relevent=full_dataset[['cook','eating_out','employment','ethnic_food','exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day']]
missing_values_count = relevent.isnull().sum()
print(missing_values_count)
# how many total missing values do we have?
total_cells = np.product(relevent.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# cook              3
# eating_out        0
# employment        9
# ethnic_food       0
# exercise         13
# fruit_day         0
# income            1
# on_off_campus     1
# pay_meal_out      0
# sports            2
# veggies_day       0
# dtype: int64
# 2.109090909090909

# %%
#As percent missing is less than 5%,we are dropping rows containing missing values.
relevent_with_no_na=relevent.dropna(axis=0)
print(relevent_with_no_na.shape[0])
# Out:
# 100

# %% [markdown]
# After a full fledged cleanup we have a clean dataframe which can be used for analysis. We have removed the rows with missing values and we have removed all the unimportant columns not required for our project.

# %% [markdown]
# # Data Visualization and Exploration

# %% [markdown]
# Now that we have our data, we need to understand it. A good way to do this is by visualising the data via graphs. Graphs help us quickly get a sense of the data, and are a much more user-friendly way of understanding data as compared to reading thousands of rows of data!

# %%
sns.pairplot(data)

# %% [markdown]
# # Boxplot

# %%
ax=data.boxplot(figsize=(15,6))
ax.set_xticklabels(ax.get_xticklabels(),rotation=50)
plt.show()

# %%
sns.set(rc = {'figure.figsize':(30,15)})
ax=sns.boxplot(data=Geolocational_exploratory_data2)
plt.title('Boxplot represention of the Dataset')
ax.set_ylim(0,7)
ax.set_yticks(range(0,7))
# Out:
# [<matplotlib.axis.YTick at 0x1ed57c4ab50>,
#  <matplotlib.axis.YTick at 0x1ed57c4a370>,
#  <matplotlib.axis.YTick at 0x1ed57c43220>,
#  <matplotlib.axis.YTick at 0x1ed57d69af0>,
#  <matplotlib.axis.YTick at 0x1ed57d6e280>,
#  <matplotlib.axis.YTick at 0x1ed57d6e9d0>,
#  <matplotlib.axis.YTick at 0x1ed57d73160>]

# %%
fig = plt.figure(figsize =(10, 20))
 
# Creating plot
ax=sns.boxplot(data=relevent_with_no_na,linewidth=5)

# show plot
plt.show()

# %%
sns.set(rc = {'figure.figsize':(10,15)})
ax=sns.countplot(x='marital_status', hue='Gender', data=Geolocational_exploratory_data2, palette=['purple','blue'])
ax.set_ylim(0,40)
ax.set_yticks(range(0,40,2))
plt.xticks([0,1],['Single','In a relationship'])
plt.legend(title='Gender', loc='upper left', labels=['Female', 'Male'])
plt.title('Count of Marital Status of All the Males and Females')
# Out:
# Text(0.5, 1.0, 'Count of Marital Status of All the Males and Females')

# %%
ax = pd.DataFrame(np.random.randn(10, 11),
                  columns=['cook', 'eating_out', 'employment','ethnic_food','exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day'])
data['X'] = pd.Series(['cook', 'eating_out', 'employment', 'ethnic_food', 'exercise',
                     'fruit_day', 'income', 'on_off_campus', 'pay_meal_out', 'sports','veggies_day'])
data['Y'] = pd.Series(['cook', 'eating_out', 'employment', 'ethnic_food', 'exercise',
                     'fruit_day', 'income', 'on_off_campus', 'pay_meal_out', 'sports','veggies_day'])
boxplot = data.boxplot(column=['income', 'cook'], by=['X', 'Y'])
# Out:
# C:\Users\kotav\AppData\Local\Temp/ipykernel_10040/4076304940.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['X'] = pd.Series(['cook', 'eating_out', 'employment', 'ethnic_food', 'exercise',
# C:\Users\kotav\AppData\Local\Temp/ipykernel_10040/4076304940.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Y'] = pd.Series(['cook', 'eating_out', 'employment', 'ethnic_food', 'exercise',

# %%
#Plotting Boxplot for cleaned data
sns.boxplot(data=data, palette="Set1").tick_params(labelsize=18.7)
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
plt.title('Heatmap represention of the Dataset')
sns.set(rc = {'figure.figsize':(30,15)})
sns.heatmap(Geolocational_exploratory_data2)
# Out:
# <AxesSubplot:title={'center':'Heatmap represention of the Dataset'}>

# %% [markdown]
# # KMeans Clustering

# %% [markdown]
# K-means clustering is a simple unsupervised learning algorithm that is used to solve clustering problems. It follows a simple procedure of classifying a given data set into a number of clusters, defined by the letter "k," which is fixed beforehand. The clusters are then positioned as points and all observations or data points are associated with the nearest cluster, computed, adjusted and then the process starts over using the new adjustments until a desired result is reached.

# %% [markdown]
# # Elbow Method

# %% [markdown]
# In cluster analysis, the elbow method is a heuristic used in determining the number of clusters in a data set. The method consists of plotting the explained variation as a function of the number of clusters, and picking the elbow of the curve as the number of clusters to use. The same method can be used to choose the number of parameters in other data-driven models, such as the number of principal components to describe a data set.

# %%
# f=[['cook','income']]
X=data[['income','cook']].dropna()
max_k = 10
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)

k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i  in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="blue", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\Users\kotav\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# # Geolocation Data

# %% [markdown]
# Geolocation is the identification of the real-world geographic location of an object. This identification is done by generating a set of geographic coordinates such a latitude and longitude through GPS and using the coordinates to determine a meaningful location. These objects could be an internet-connected computer, mobile phone, table or radar source.
#
# Two different types of data can be collected through geolocation:
#
# Active User/Device Based Information
# Passive Server-Based Lookup/Data Correlation
# By collecting these both types of data, it allows them to be cross-referenced against one another to create the most accurate geolocation result.

# %%
import googlemaps
import pprint

# %%
api_key="AIzaSyC_yym2grlJqteBmfP4-9qp93YIh3i712k"

gmaps=googlemaps.Client(key = api_key)

# %%
results_food1 = gmaps.places_nearby(location = "23.23577616704816, 77.40268416994763", radius=15000, type=['restaurant'])
results_food2 = gmaps.places_nearby(location = "23.23577616704816, 77.40268416994763", radius=15000, type=['cafe'])
results_food = {**results_food1,**results_food2}
pprint.pprint(results_food)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDkkq4UiTgOKsf6wbgGuDy0H57KxGioD838U1X_me-6mzXNHAdtajK7l0ifdKqIuuqZH9eVRyBXeuZvBF1N5_jT1h39EfHjbLI2wt_xnyS4hXnOF3mB54nvMvJTiuHabvGZQUpM0WLLxVofFrRyCMfpj9kvUfhl4aqmG7da9o1rxgoqQctr402c_SsromsEfkrgz1PWR5mBUqy7a3VbjOG26jCfQ8GJsrFzrZCfg3JvpQT7pZUdxyUvkvG8HXEztEAeRWbH0rXcwnBkPIhXMfDUmHWJgVAivAGZh3-2ijknmewfrTqou8pKpCNk8VcJHtHi5wb8D0TVfq_rUXDsoxD1NBFmnN6Z_YJQolKuZJYGf0lPqkIgaR_eAiGirS6XF77VCggE7m6pqIuUOR7HC2O7FIGaXuIOEzglmNFWXEEqwGavgeno',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.236551, 'lng': 77.4001953},
#                            'viewport': {'northeast': {'lat': 23.2379460302915,
#                                                       'lng': 77.4015009802915},
#                                         'southwest': {'lat': 23.2352480697085,
#                                                       'lng': 77.3988030197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'New Inn Restaurant & Coffee House',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2610,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108022963919361589326">Dhirendra '
#                                                 'D</a>'],
#                           'photo_reference': 'Aap_uEBencBGaxWrBuW25_PNbpehSIfaXaSNRN6q32xdHcvSj82AKxOSbcpVLmJpHeQjLXpqk5YtNmRJ4zvnm1ev-SMbiPfRk_1uzsMrAHB9NdD1txzgnbuxxMTmFUEpSKFrn_Emah8utMPwH9-2mtrchC6FBPmGKIcg8TuYtSs0QOpS9uY',
#                           'width': 4640}],
#               'place_id': 'ChIJKQovNLlCfDkR2X4kQjn5ys8',
#               'plus_code': {'compound_code': '6CP2+J3 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP2+J3'},
#               'price_level': 2,
#               'rating': 3.7,
#               'reference': 'ChIJKQovNLlCfDkR2X4kQjn5ys8',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 837,
#               'vicinity': '28, Bhadbhada Road, New Market, TT Nagar, Bhopal'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': 23.2340647,
#                                         'lng': 77.40276159999999},
#                            'viewport': {'northeast': {'lat': 23.2353872302915,
#                                                       'lng': 77.40407433029151},
#                                         'southwest': {'lat': 23.2326892697085,
#                                                       'lng': 77.40137636970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Café Coffee Day - Usha Preet Complex',
#               'permanently_closed': True,
#               'photos': [{'height': 774,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100411763264161190291">Ani</a>'],
#                           'photo_reference': 'Aap_uECTfO35Cz0sJ8VeYAxDCcKx2wfr2wTU3Ys17QegKt90vprCd7-t71F1uP3uTJYPt9K7mCaAg09hJ6VdRG0-3Qf9UGUPr5cGdeiFGYUF2ipqWswxRrot9V7ifXjAUe0GGoVR62ovrsYfQ-rSmIKuL1wPoChr1qCJLVf_ykNC2ZfcMixL',
#                           'width': 1032}],
#               'place_id': 'ChIJyZqdspVCfDkR6YL3ElvMdcI',
#               'plus_code': {'compound_code': '6CM3+J4 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM3+J4'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJyZqdspVCfDkR6YL3ElvMdcI',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 158,
#               'vicinity': 'G 9 10, Usha Preet Complex, Maliviya Nagar, Malviya '
#                           'Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.22819089999999,
#                                         'lng': 77.39280819999999},
#                            'viewport': {'northeast': {'lat': 23.2296070802915,
#                                                       'lng': 77.3940669302915},
#                                         'southwest': {'lat': 23.22690911970849,
#                                                       'lng': 77.39136896970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': "shasha's Cafe",
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJeUp3f8dCfDkRF8uLI1W-2NM',
#               'plus_code': {'compound_code': '69HV+74 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69HV+74'},
#               'rating': 4,
#               'reference': 'ChIJeUp3f8dCfDkRF8uLI1W-2NM',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 11,
#               'vicinity': 'Bhadbhada Road, Shastri Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2468709, 'lng': 77.4165297},
#                            'viewport': {'northeast': {'lat': 23.2482165302915,
#                                                       'lng': 77.41787268029151},
#                                         'southwest': {'lat': 23.2455185697085,
#                                                       'lng': 77.4151747197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Guddu Tea Stall And Restaurant',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106660061463602699439">waqar '
#                                                 'Khan</a>'],
#                           'photo_reference': 'Aap_uEATuxnvwNuHTDznU83wjspuYPXZZdcNadDwdC-yy7D3_7hhCjdpPoIS5mV7ibbxkemDKFYPW5M-TNn8hDAWz332zHkYXI-oo9HOMicQa4AcDzTTnK4poPdMl-jjpYkflcgq7CpBo7j_IOsRDmC0xlnJiSyKsFElc-EBJHpSWR4ednGA',
#                           'width': 1080}],
#               'place_id': 'ChIJ-4c8b4RCfDkR9iJZc1K73pI',
#               'plus_code': {'compound_code': '6CW8+PJ Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CW8+PJ'},
#               'rating': 3.9,
#               'reference': 'ChIJ-4c8b4RCfDkR9iJZc1K73pI',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 72,
#               'vicinity': 'Jail Rd, 45, Jail Road, C.L.Colony, Jahangirabad, '
#                           'Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2482578, 'lng': 77.4155373},
#                            'viewport': {'northeast': {'lat': 23.2496068302915,
#                                                       'lng': 77.41688908029151},
#                                         'southwest': {'lat': 23.2469088697085,
#                                                       'lng': 77.41419111970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Azamgarh (Azmi Palace)',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1757,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114530807746972384301">Tausif '
#                                                 'Ahmad</a>'],
#                           'photo_reference': 'Aap_uEDuZlFmTYb03ETUukw_3H75d_ZmJ-sTqWsNLgmT4gylc8I2X9DFgskQiUPyAjZlKXfZZunIO4783eSGYwy8lkf0yt38dMSdCZ2_WdV0YOAwAWAQiQnTh4kZvqylfHdtTw7kEy76avj0AwGy0WwPSsJcDkY8KLfrFIapeb7VEGIAzMRv',
#                           'width': 2824}],
#               'place_id': 'ChIJ5WA1f4NCfDkR5H7UZ_fh_XQ',
#               'plus_code': {'compound_code': '6CX8+86 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CX8+86'},
#               'rating': 4,
#               'reference': 'ChIJ5WA1f4NCfDkR5H7UZ_fh_XQ',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 342,
#               'vicinity': 'Post Office Road, Pratap Nagar, Jahangirabad, '
#                           'Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.235122, 'lng': 77.401921},
#                            'viewport': {'northeast': {'lat': 23.2364242302915,
#                                                       'lng': 77.40320788029152},
#                                         'southwest': {'lat': 23.2337262697085,
#                                                       'lng': 77.4005099197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Ambrosia Cafe & Restaurant',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 323,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114523295375455650197">Ambrosia '
#                                                 'Cafe &amp; Restaurant</a>'],
#                           'photo_reference': 'Aap_uEDLTaonrB4fCnxu__OYiYXEggaj-O1UTDmdEnc79X1b_hH3AjABtD39ANg-PqqCV1GiUEeRkapkqHhpTvVXV8TZrX6ztTxIa3acOYxfuwzRKtFatw89h9lCQSNnlLTvJ1UOVlAuphwrHtQlpFRipwV09z6C0fXxsBOPj70BDDzbxs-i',
#                           'width': 576}],
#               'place_id': 'ChIJMUoGB5ZCfDkR_jCAD3RXcKE',
#               'plus_code': {'compound_code': '6CP2+2Q Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP2+2Q'},
#               'rating': 3.9,
#               'reference': 'ChIJMUoGB5ZCfDkR_jCAD3RXcKE',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 144,
#               'vicinity': '35 New Market, Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2347121, 'lng': 77.4016189},
#                            'viewport': {'northeast': {'lat': 23.2360548302915,
#                                                       'lng': 77.4028891302915},
#                                         'southwest': {'lat': 23.23335686970849,
#                                                       'lng': 77.40019116970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Prince Jaljira Center',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 801,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100947477526746501247">Rahul '
#                                                 'vishwkarma</a>'],
#                           'photo_reference': 'Aap_uEDIZX0Iwx-lG9tWDB3WWfQZgxkfJJOn51I5F4hdzoOd048AkfwystxdZnU3J5XvEfdapbNqrBPK_3bdMCdaSsqpOIQ8vwqdC0J65i1i4FiZ57RqEaweRylLUoBKteuvkw1YPejaMVghqgzuSpLEkQ8mZcVrrhevgdkcvaSRwZBFawFX',
#                           'width': 641}],
#               'place_id': 'ChIJXf2Oz4hDfDkRWkk7htML9CM',
#               'plus_code': {'compound_code': '6CM2+VJ Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM2+VJ'},
#               'rating': 3.7,
#               'reference': 'ChIJXf2Oz4hDfDkRWkk7htML9CM',
#               'scope': 'GOOGLE',
#               'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': "Indian Cafe house back Side Main rode New auto''bus "
#                           'stop, new market Malviya Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': 23.23468979999999,
#                                         'lng': 77.4012475},
#                            'viewport': {'northeast': {'lat': 23.2357549802915,
#                                                       'lng': 77.4025716802915},
#                                         'southwest': {'lat': 23.2330570197085,
#                                                       'lng': 77.39987371970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Keventers',
#               'permanently_closed': True,
#               'photos': [{'height': 2064,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106560982065217004734">Sanskar '
#                                                 'Rai</a>'],
#                           'photo_reference': 'Aap_uEBWkxTp76G4AgPso1ygSKlHrPBwuSxC08M9nkQP3rx51uBevZhcy865jOY4Ah5dneGl4Cy1bXNYlw2nMY0bNtkan0FbxAuPrWkXTPHXkqZTUdAx_OmvTofQJJ8SdXl6aq64ezLapwOzhZO2Rrs2hH1riQbubqeUorku_pAsb6tkd6VZ',
#                           'width': 2752}],
#               'place_id': 'ChIJ55q_Ab5CfDkRnyy3vXfan4c',
#               'plus_code': {'compound_code': '6CM2+VF Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM2+VF'},
#               'price_level': 2,
#               'rating': 4.3,
#               'reference': 'ChIJ55q_Ab5CfDkRnyy3vXfan4c',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 82,
#               'vicinity': 'Shop No. 2, Plot No. 5, TT Nagar New Market, Oppo. '
#                           'Manyawar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2356358, 'lng': 77.4006229},
#                            'viewport': {'northeast': {'lat': 23.2369865802915,
#                                                       'lng': 77.40197168029151},
#                                         'southwest': {'lat': 23.2342886197085,
#                                                       'lng': 77.3992737197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Tandoori Chai',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3120,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113639660146242653507">Tandoori '
#                                                 'Chai</a>'],
#                           'photo_reference': 'Aap_uEBLV5nV_ePwFvK8L-XM2tlCgPOi7thAeZ78R9zZfeXUfmwCq8gzldKjJsdqlV252ct0umir8dsRo9moUNthrv6XQ_aOnrAI1nHueWI40zBxKZquu_P1bzbyv5NUuUF23-mHqDE7PxaTjkQWaEGI4Sn_TttoDsLfiyKSkxdayoOBQSBZ',
#                           'width': 4160}],
#               'place_id': 'ChIJ5WRghElDfDkRbjkUuTW8Vg0',
#               'plus_code': {'compound_code': '6CP2+76 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP2+76'},
#               'rating': 5,
#               'reference': 'ChIJ5WRghElDfDkRbjkUuTW8Vg0',
#               'scope': 'GOOGLE',
#               'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 6,
#               'vicinity': '5, New Market, Samta Chowk, TT Nagar, Bhopal'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': 23.2376751, 'lng': 77.402362},
#                            'viewport': {'northeast': {'lat': 23.2392390302915,
#                                                       'lng': 77.40352258029151},
#                                         'southwest': {'lat': 23.2365410697085,
#                                                       'lng': 77.40082461970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Jyoti Tea Stall',
#               'permanently_closed': True,
#               'place_id': 'ChIJmdbtM5ZCfDkRW0B2UYQPCvU',
#               'plus_code': {'compound_code': '6CQ2+3W Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CQ2+3W'},
#               'reference': 'ChIJmdbtM5ZCfDkRW0B2UYQPCvU',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'cafe',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '78, Roshanpura Road, Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2380818, 'lng': 77.4018326},
#                            'viewport': {'northeast': {'lat': 23.2394587802915,
#                                                       'lng': 77.4031594802915},
#                                         'southwest': {'lat': 23.2367608197085,
#                                                       'lng': 77.4004615197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Bhopali chai sutta',
#               'place_id': 'ChIJfZ6iHFFDfDkRS0Wxh4LZbro',
#               'plus_code': {'compound_code': '6CQ2+6P Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CQ2+6P'},
#               'reference': 'ChIJfZ6iHFFDfDkRS0Wxh4LZbro',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'vicinity': 'Roshanpura, Roshanpura Slums, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2345912, 'lng': 77.4002836},
#                            'viewport': {'northeast': {'lat': 23.23591873029151,
#                                                       'lng': 77.4016339302915},
#                                         'southwest': {'lat': 23.2332207697085,
#                                                       'lng': 77.39893596970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Super tea coffee stall',
#               'place_id': 'ChIJY7esCC1DfDkR7WlZVpzlojs',
#               'plus_code': {'compound_code': '6CM2+R4 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM2+R4'},
#               'rating': 5,
#               'reference': 'ChIJY7esCC1DfDkR7WlZVpzlojs',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'New Market Main Road, Near Hakeem Hotel, New '
#                           'Market, STT Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2334067, 'lng': 77.4042881},
#                            'viewport': {'northeast': {'lat': 23.2347304802915,
#                                                       'lng': 77.4056028302915},
#                                         'southwest': {'lat': 23.2320325197085,
#                                                       'lng': 77.4029048697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Milkshake Kulture',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3120,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104139039345638142310">Aditya '
#                                                 'Narad</a>'],
#                           'photo_reference': 'Aap_uECjUSKFkb0lh9EhHZZfancoEQrwvUGVrDNqtzDyywy5neU0JaOrGWAmEdRmrB1QE8J6JYNNgx22r3CHwkJN3WdOCApuvC8wd2RY_f0BnVdWlGTpxQdbBMykovl5C5m_T1Tx4eEtuLx-ynaGKkpjQ355j5Q6ZbWf0Wq9Rl5mmjLaPVLi',
#                           'width': 4160}],
#               'place_id': 'ChIJkZCCTJRCfDkRXBqhzIBhXsg',
#               'plus_code': {'compound_code': '6CM3+9P Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM3+9P'},
#               'price_level': 2,
#               'rating': 4.1,
#               'reference': 'ChIJkZCCTJRCfDkRXBqhzIBhXsg',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 221,
#               'vicinity': 'No 129, Malviya Nagar, Near Emerge Store, Opposite '
#                           'Gammon Mall'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2334186,
#                                         'lng': 77.40434180000001},
#                            'viewport': {'northeast': {'lat': 23.2347289302915,
#                                                       'lng': 77.40563618029151},
#                                         'southwest': {'lat': 23.2320309697085,
#                                                       'lng': 77.4029382197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'DIET DESSERT CO.',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 590,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107257779082644669011">Sawan '
#                                                 'Soni</a>'],
#                           'photo_reference': 'Aap_uEBG0tnYqIqy6m88r2gCtxNjPZKFUTxOM5J0WIKC4tNts6SZi6ziCssfXDE6kD7YjhS-szOjqAXfBBdDSVZ79ALitdW_2MZ4rYY9ZdgPD_cfwUq0pYLivXBfTseRY_G4hrgiCHBc9x9tzynI0C1UA9xVNcryHuOlJrkGphKcc_bOBjT_',
#                           'width': 1280}],
#               'place_id': 'ChIJAVQT4h9DfDkR4rKOgILG7M8',
#               'plus_code': {'compound_code': '6CM3+9P Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM3+9P'},
#               'rating': 5,
#               'reference': 'ChIJAVQT4h9DfDkR4rKOgILG7M8',
#               'scope': 'GOOGLE',
#               'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 4,
#               'vicinity': 'Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2370282, 'lng': 77.399886},
#                            'viewport': {'northeast': {'lat': 23.2383753802915,
#                                                       'lng': 77.40123678029151},
#                                         'southwest': {'lat': 23.2356774197085,
#                                                       'lng': 77.39853881970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'Famous Soda Shop',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106450442895896388886">Saket '
#                                                 'Rusia</a>'],
#                           'photo_reference': 'Aap_uEDK1r1vaSLOAZGye6vdI1V6v7Q7x_tI4T5VpliUQNhGVIfIouTBbjXLaGiKnEF4xmKGxG217QRgbhFZ_1ZqzaRN8fZK8uRDliqGHzRRMOPsyt1XkOe35xlKUknIjkgTK31icmoYoqinhVQZIrBS_3hKAi9naQggHmJ2dpcuhWC_8WJ_',
#                           'width': 4608}],
#               'place_id': 'ChIJB8oFn71CfDkRUWinsqE75xI',
#               'plus_code': {'compound_code': '69PX+RX Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69PX+RX'},
#               'rating': 5,
#               'reference': 'ChIJB8oFn71CfDkRUWinsqE75xI',
#               'scope': 'GOOGLE',
#               'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'G.T.B Complex, S-17, Bhadbhada Road, New Market, '
#                           'North TT Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2367968, 'lng': 77.3992241},
#                            'viewport': {'northeast': {'lat': 23.2381729302915,
#                                                       'lng': 77.40054768029151},
#                                         'southwest': {'lat': 23.2354749697085,
#                                                       'lng': 77.3978497197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': 'KULHADWAALA (DESI CHAI KA ADDA)',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 405,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112920510830324043284">KULHADWAALA '
#                                                 '(DESI CHAI KA ADDA)</a>'],
#                           'photo_reference': 'Aap_uEA3SUhJ2RNe1ysBqmYJeEUxg8viVLetA3Jlaf3m7HWQs062RekHmbAWLSrZguNJsTkfqDHqTG5qowg0eHGnjKrJexSLDGRmhtvWSooLD1XbsHzUk0zq9HlG5M0Y8AMsPaTxS5kY3e9rs24bkZENyFARrDSPGVAlEVcj7hP5E13efNez',
#                           'width': 720}],
#               'place_id': 'ChIJjW4uoyRDfDkRrPIr28rMpc8',
#               'plus_code': {'compound_code': '69PX+PM Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69PX+PM'},
#               'rating': 1,
#               'reference': 'ChIJjW4uoyRDfDkRrPIr28rMpc8',
#               'scope': 'GOOGLE',
#               'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'behind HAWAII ADDA, S-50 GTB COMPLEX, behind HAWAII '
#                           'ADDA, New Market, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2362543, 'lng': 77.3990673},
#                            'viewport': {'northeast': {'lat': 23.2375721302915,
#                                                       'lng': 77.40044563029151},
#                                         'southwest': {'lat': 23.23487416970849,
#                                                       'lng': 77.39774766970851}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': "The Smokin'Shawarma",
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113086910395189390158">The '
#                                                 'Smokin&#39;Shawarma</a>'],
#                           'photo_reference': 'Aap_uEAMNTI6KCMCb1gjBjNukB-rjCcsq4n6DbeWh_lw8yRkzBF-fr50ksCv32-bM_8Q9tMdoa60cbZMG26p-Hq9oXnAgMRZpq-cbQwfQq3weuT7MtxHCnIpdA6fUbdX6x0eSa-0rjaKqkR9XvIZph3l7a7YPCEwqbiy6VW1zRH9e4fSVOfa',
#                           'width': 3024}],
#               'place_id': 'ChIJK_nH2PJDfDkRDsq2AJo4ej4',
#               'plus_code': {'compound_code': '69PX+GJ Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69PX+GJ'},
#               'reference': 'ChIJK_nH2PJDfDkRDsq2AJo4ej4',
#               'scope': 'GOOGLE',
#               'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#               'vicinity': 'near Chai Sutta bar, S-52 GTB complex, Rangmahal '
#                           'Chauraha, near Chai Sutta bar, New Market, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2386594, 'lng': 77.4007376},
#                            'viewport': {'northeast': {'lat': 23.2399797302915,
#                                                       'lng': 77.40204498029149},
#                                         'southwest': {'lat': 23.2372817697085,
#                                                       'lng': 77.39934701970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Ali Tea Stall',
#               'place_id': 'ChIJQ-U9Zb1CfDkRzk6QwKWqj8k',
#               'reference': 'ChIJQ-U9Zb1CfDkRzk6QwKWqj8k',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'cafe',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'vicinity': '6CQ2+F79, Roshanpura Slums, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2349989, 'lng': 77.3989014},
#                            'viewport': {'northeast': {'lat': 23.2365375302915,
#                                                       'lng': 77.4000732302915},
#                                         'southwest': {'lat': 23.2338395697085,
#                                                       'lng': 77.39737526970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Bake-n-shake',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1952,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108239414393426356537">Yogendra '
#                                                 'Sagar Mishra</a>'],
#                           'photo_reference': 'Aap_uEA6viy3nx7Ir44eUU-9HGeISAluL2OHkKiIHUgw_oP75uQ_5DbKpWYWsats_94qvqkoT9p-6jSWxeJCSP8uiW8pjqhhy83N6eKGiYUqZBwDtpQCYffoBbcRQO4_JIqTQpFG9ymPHpeaeU4aK-fWffZ2SaySqMUvwsJuj6HepVjlNkUg',
#                           'width': 4160}],
#               'place_id': 'ChIJLYST1r1CfDkRlqlZd50lyWQ',
#               'plus_code': {'compound_code': '69MX+XH Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69MX+XH'},
#               'price_level': 2,
#               'rating': 4.3,
#               'reference': 'ChIJLYST1r1CfDkRlqlZd50lyWQ',
#               'scope': 'GOOGLE',
#               'types': ['restaurant',
#                         'cafe',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 2089,
#               'vicinity': 'Rangmahal Ciniplex Compund, 43, Bhadbhada Road, New '
#                           'Market, STT Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.234651, 'lng': 77.398487},
#                            'viewport': {'northeast': {'lat': 23.2361849302915,
#                                                       'lng': 77.39964033029152},
#                                         'southwest': {'lat': 23.23348696970849,
#                                                       'lng': 77.39694236970851}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/cafe_pinlet',
#               'name': "Teafriend's New Market",
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101402539313494632143">Neha '
#                                                 'Lahariya</a>'],
#                           'photo_reference': 'Aap_uEDPg3j1i23BvEWbyzLsWm_TkeWcpQYBFTVbppqPJ9GLbS6AJUCHRoBhfSJ-mDkvxMhelX2HbrxXBMuIxJj634sLt9NAVqOGCGUGjr4yIYA9RoQs3JNOjQAoDZzTE1sxfgmnf1RuisSQZKehEey4corC59YVeoJCdwN4mBfmibGqjBgG',
#                           'width': 3120}],
#               'place_id': 'ChIJE-Dgf75CfDkRHMn_GDEeEks',
#               'plus_code': {'compound_code': '69MX+V9 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69MX+V9'},
#               'rating': 4.2,
#               'reference': 'ChIJE-Dgf75CfDkRHMn_GDEeEks',
#               'scope': 'GOOGLE',
#               'types': ['cafe',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 25,
#               'vicinity': 'near Rangmahal talkies, Apoorti Super Bazaar '
#                           'campus, near Rangmahal talkies, TT Nagar, Bhopal'}],
#  'status': 'OK'}

# %%
results_gym = gmaps.places_nearby(location = "23.23577616704816, 77.40268416994763", radius=15000, type=['gym'])
pprint.pprint(results_gym)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEBxKJ8viG4OwKqW_Y2zH4pr6GeEHnhgFg_wlsNL6C8DHKwxUUlCZnbNEvWFr5ZwlqyChcruMBH0SDSWJ_IZAsV4mqBygzvd-ZgO7gDMGVuRyZdobzA4Vvi3Dxkmd5A26z6xb3oLCwxzKVROK6WKX2-vXs6g8vHHuFK1xNdpJU-dmuACU7eAHDTGJj5YLmZ0nTaMa4iieuabOlbpKCn3YwA4ENNxqVjeWc86ZckmLeVCGsqvHq_8PmFEg4JKaZu8kKh0csdllrGBOKc-T6BMC13jPXlkbxMrfbhRDKsD8EK8-bXdSitNgM_L3JE0muyN45Hp7mSwN3eghsAz5im-Sc_O9pwqmX63zNfg43AC5w_C_JTNvQHUpB3TS2SQETgi4GZIQi5nG32Ee4L-j2U3CGQX-GDCQxEcwGYrEoCbi5-NOfDijuk',
#  'results': [{'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': 23.2279326, 'lng': 77.4032551},
#                            'viewport': {'northeast': {'lat': 23.2292923802915,
#                                                       'lng': 77.4047051302915},
#                                         'southwest': {'lat': 23.2265944197085,
#                                                       'lng': 77.40200716970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'U.S. Fitness Club & Gym',
#               'permanently_closed': True,
#               'place_id': 'ChIJOcFFwupCfDkRqMU9QCvIVv4',
#               'plus_code': {'compound_code': '6CH3+58 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CH3+58'},
#               'rating': 3.4,
#               'reference': 'ChIJOcFFwupCfDkRqMU9QCvIVv4',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 33,
#               'vicinity': 'Jain Mandir Road, Mata Mandir Opp.Platinum Plaza, '
#                           'Old Subhash Nagar Colony, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.231111, 'lng': 77.4115183},
#                            'viewport': {'northeast': {'lat': 23.2324609302915,
#                                                       'lng': 77.4128652802915},
#                                         'southwest': {'lat': 23.2297629697085,
#                                                       'lng': 77.41016731970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Vishal Fitness',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2250,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101655959911285108131">Aasif '
#                                                 'Khan</a>'],
#                           'photo_reference': 'Aap_uECsbcU7-cXVA_EFauM6V0l4btrcnp972WDEUPqLTpKBuPX3paNy-j1tZFk0gs5PsEtvSkgdAk-BhMXSehvR3CpicjWfSBmlQauEmR7ewp30KqJsygh3HtAqBnWq3rAwgUMGRqqun0pSY5X5QW0JDLqgczpKVKABByJm2Fn_xXA6aBtv',
#                           'width': 4000}],
#               'place_id': 'ChIJp6pIpJJCfDkRnfDrCIjBGWE',
#               'plus_code': {'compound_code': '6CJ6+CJ Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CJ6+CJ'},
#               'rating': 4.3,
#               'reference': 'ChIJp6pIpJJCfDkRnfDrCIjBGWE',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 180,
#               'vicinity': 'Link Road 1, 2nd Stop, STT Nagar, Shivaji Nagar, '
#                           'Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2297929, 'lng': 77.3938455},
#                            'viewport': {'northeast': {'lat': 23.2311443302915,
#                                                       'lng': 77.39519778029151},
#                                         'southwest': {'lat': 23.2284463697085,
#                                                       'lng': 77.39249981970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Amway Distributor',
#               'place_id': 'ChIJa7aHlLhCfDkRWx2JtUC8E-o',
#               'plus_code': {'compound_code': '69HV+WG Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69HV+WG'},
#               'rating': 3.7,
#               'reference': 'ChIJa7aHlLhCfDkRWx2JtUC8E-o',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': 'Unnamed Road, Jawahar Chowk, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2436298, 'lng': 77.3930505},
#                            'viewport': {'northeast': {'lat': 23.2449958802915,
#                                                       'lng': 77.3944212302915},
#                                         'southwest': {'lat': 23.24229791970849,
#                                                       'lng': 77.39172326970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/hospital-71.png',
#               'icon_background_color': '#F88181',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hospital-H_pinlet',
#               'name': 'The Fitness World By C Max',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJUY0tUqRCfDkRnHRnJVdtkW0',
#               'plus_code': {'compound_code': '69VV+F6 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69VV+F6'},
#               'rating': 5,
#               'reference': 'ChIJUY0tUqRCfDkRnHRnJVdtkW0',
#               'scope': 'GOOGLE',
#               'types': ['hospital',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': '27/B, Ali Ahina Building, Jehan Numa Rd, Rustam '
#                           'Ahaata Khan, Opp. Shymala Hills Police Station, '
#                           'Krishna Nagar, Shymala Hills, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2476529, 'lng': 77.39643},
#                            'viewport': {'northeast': {'lat': 23.2490507302915,
#                                                       'lng': 77.39787418029151},
#                                         'southwest': {'lat': 23.24635276970849,
#                                                       'lng': 77.3951762197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'The Fitness World Gym',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104144364126295798940">The '
#                                                 'Fitness World Gym</a>'],
#                           'photo_reference': 'Aap_uEDZahp43whck3_5zop4HKCcNZGxfpwkBkIzX_sC-rFZYiDnoj3xpIWveQyiO9OFXOR6o-43otAYF27D0gT-XfWtMNxKuzREwUhxzLiCLHMShXYzvu9FhNmn92Q-K3DApzlStkgyQFC2FFz7gOLLASGrhjYLxOO8eoXhuDQ6rFM9xd1A',
#                           'width': 3024}],
#               'place_id': 'ChIJM5aSR6FCfDkRfpwTr4OLu2k',
#               'plus_code': {'compound_code': '69XW+3H Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69XW+3H'},
#               'rating': 3.8,
#               'reference': 'ChIJM5aSR6FCfDkRfpwTr4OLu2k',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 46,
#               'vicinity': 'Kamla Park Road, Yamuma Square, Polytechnic Square, '
#                           'Krishna Nagar, Shymala Hills, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2429635, 'lng': 77.38747},
#                            'viewport': {'northeast': {'lat': 23.2442634302915,
#                                                       'lng': 77.38890903029152},
#                                         'southwest': {'lat': 23.2415654697085,
#                                                       'lng': 77.3862110697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Essentia Spa',
#               'place_id': 'ChIJWWacBq9CfDkRmRVpPEevKx8',
#               'reference': 'ChIJWWacBq9CfDkRmRVpPEevKx8',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'vicinity': '69VP+5XQ, Shymala Hills, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.235542,
#                                         'lng': 77.40127799999999},
#                            'viewport': {'northeast': {'lat': 23.2368909802915,
#                                                       'lng': 77.4026269802915},
#                                         'southwest': {'lat': 23.2341930197085,
#                                                       'lng': 77.3999290197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Akhil Sports',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJEUtB3gJDfDkR7JttKHLPX4M',
#               'plus_code': {'compound_code': '6CP2+6G Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP2+6G'},
#               'rating': 4,
#               'reference': 'ChIJEUtB3gJDfDkR7JttKHLPX4M',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'New Market Main Road, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.238316, 'lng': 77.401282},
#                            'viewport': {'northeast': {'lat': 23.2397154302915,
#                                                       'lng': 77.4027455302915},
#                                         'southwest': {'lat': 23.2370174697085,
#                                                       'lng': 77.40004756970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'VLCC Wellness Center, (Malviya Nagar, New Market '
#                       'Bhopal)',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112261654152398415921">Civilian '
#                                                 'Singh</a>'],
#                           'photo_reference': 'Aap_uEBO7nKs35Z5BWUsB3Tqeus8uwAID4s1py5hlOdm00XIJcQLXVnPg6_eUrTYj_cXXWty7hVR25wTAeC16nrnDJW3-x43ZMJLUTO1c90W2s_X6Yoy8aAIZiwND2mzwbipwRglKQsNH5oyJ_QuUO5FIduw-9IVoJSRCSjPPf3CS9n7pgwu',
#                           'width': 2048}],
#               'place_id': 'ChIJ____q5dCfDkRS6xIGKXtseg',
#               'plus_code': {'compound_code': '6CQ2+8G Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CQ2+8G'},
#               'rating': 4.5,
#               'reference': 'ChIJ____q5dCfDkRS6xIGKXtseg',
#               'scope': 'GOOGLE',
#               'types': ['beauty_salon',
#                         'hair_care',
#                         'doctor',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 388,
#               'vicinity': 'above Virasat Showroom, 47/A,First floor Malviya '
#                           'Nagar, New Market, above Virasat Showroom, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2332418,
#                                         'lng': 77.40481419999999},
#                            'viewport': {'northeast': {'lat': 23.2345981802915,
#                                                       'lng': 77.4061625302915},
#                                         'southwest': {'lat': 23.2319002197085,
#                                                       'lng': 77.40346456970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'STAY HEALTHY AND FIT CENTER',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2448,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112264113609672500332">Akhilesh '
#                                                 'patle</a>'],
#                           'photo_reference': 'Aap_uEDJM9Ey83ie_csBy_sfhcInS9txQZJnzuQgxZIsxfrc5fgE8bxWYqehtxftFX3ptd7jLMrjcenrdTQPQqG7xgaOoX33OmdoAaX52Ihzz34FdkksSNQYwY3AavRaQ3kAL3DQ_H49768nSegsEIntNn_0S-TGjq2ubqOVb0j98cuukeVF',
#                           'width': 3264}],
#               'place_id': 'ChIJn4YJT5RCfDkRI6il6T2wgqg',
#               'plus_code': {'compound_code': '6CM3+7W Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM3+7W'},
#               'rating': 5,
#               'reference': 'ChIJn4YJT5RCfDkRI6il6T2wgqg',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Link Road 1, Harshavardhan Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2356251, 'lng': 77.3983635},
#                            'viewport': {'northeast': {'lat': 23.2369005802915,
#                                                       'lng': 77.39978693029151},
#                                         'southwest': {'lat': 23.2342026197085,
#                                                       'lng': 77.39708896970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Gymnasium (Body Temple)',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108182741122486795125">Ayush '
#                                                 'WanjaRii</a>'],
#                           'photo_reference': 'Aap_uECiDMul1e_M-lYkAK3AAVWEbzUTbPQFxVjvKCsrw_F8pNsHodZVfrAP_ondvZcVq4mqxlmmV9sOqgJhayozWvAwHPr4uJonG3_-ocqXbGySY3hAaww6Al1wPnoCitM8YY3_A_HJqL_DcXyqUc9su4sUF2OrtTf44iHNIgVc8HQlaM6K',
#                           'width': 720}],
#               'place_id': 'ChIJDZ_hMrxCfDkRzYOkWpee1pQ',
#               'plus_code': {'compound_code': '69PX+78 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69PX+78'},
#               'rating': 4.2,
#               'reference': 'ChIJDZ_hMrxCfDkRzYOkWpee1pQ',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 33,
#               'vicinity': 'Opp. Rangmahal talkies, North TT Nagar, TT Nagar, '
#                           'Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2393858, 'lng': 77.4052682},
#                            'viewport': {'northeast': {'lat': 23.2407782802915,
#                                                       'lng': 77.4065833802915},
#                                         'southwest': {'lat': 23.2380803197085,
#                                                       'lng': 77.40388541970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Powermax Fitness',
#               'photos': [{'height': 608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108863290698227282925">Powermax '
#                                                 'Fitness</a>'],
#                           'photo_reference': 'Aap_uEDl6Bu729oxPdLZ6OK46VISQhUYCqoj41YKBS3N0S9jYuaec22XZhhTfxrDpB5u-yJLfiO06CEzXkwFupuG59TMxrByUPda84n7jyB1DCnmQJtB8yGeGESe8hv0zX5LDVoArTc-S4u75P7A5-dVRA0VKwNWySBjk4wbR6Mw53xVXVZp',
#                           'width': 1085}],
#               'place_id': 'ChIJa310p9VDfDkR7fFg8TwuB4Q',
#               'plus_code': {'compound_code': '6CQ4+Q4 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CQ4+Q4'},
#               'rating': 1,
#               'reference': 'ChIJa310p9VDfDkR7fFg8TwuB4Q',
#               'scope': 'GOOGLE',
#               'types': ['gym',
#                         'health',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Advance Fitness, 6 AB, Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2312689, 'lng': 77.3991283},
#                            'viewport': {'northeast': {'lat': 23.23261608029151,
#                                                       'lng': 77.40039348029151},
#                                         'southwest': {'lat': 23.2299181197085,
#                                                       'lng': 77.3976955197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Control Room And Reception',
#               'place_id': 'ChIJiRK3r79CfDkRjxZyzrHQDEk',
#               'rating': 3,
#               'reference': 'ChIJiRK3r79CfDkRjxZyzrHQDEk',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': '69JX+GM2, STT Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2333915, 'lng': 77.3960883},
#                            'viewport': {'northeast': {'lat': 23.2347553802915,
#                                                       'lng': 77.3974233802915},
#                                         'southwest': {'lat': 23.2320574197085,
#                                                       'lng': 77.3947254197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'he man gents parlour manoj umre',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJb13Ftr5CfDkR0YBtKYrPeUw',
#               'reference': 'ChIJb13Ftr5CfDkR0YBtKYrPeUw',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'vicinity': '69MW+9C4, North TT Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2326626, 'lng': 77.3947371},
#                            'viewport': {'northeast': {'lat': 23.2340200302915,
#                                                       'lng': 77.39609763029152},
#                                         'southwest': {'lat': 23.23132206970849,
#                                                       'lng': 77.39339966970851}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'The Mark Fitness Care Gym',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJs7jZErlCfDkRvzNfN6ljePs',
#               'rating': 4.3,
#               'reference': 'ChIJs7jZErlCfDkRvzNfN6ljePs',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 17,
#               'vicinity': '69MV+3V9, MLA Quarters, North TT Nagar, TT Nagar, '
#                           'Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.236776, 'lng': 77.3938388},
#                            'viewport': {'northeast': {'lat': 23.2381163302915,
#                                                       'lng': 77.39520983029149},
#                                         'southwest': {'lat': 23.2354183697085,
#                                                       'lng': 77.39251186970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Bhagvati Motor',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111020206087654764048">Ram '
#                                                 'Gour</a>'],
#                           'photo_reference': 'Aap_uED95B_Ur6aS0hhryKpzLQznyJPGychAENZnIIfz5syVM4HE5G1gdHErDstrIKsQHz2Ecfc4PcNZV1ha1VwBrmPHGR3DwOdwT3f_-t-iDtE1eFOzHk_9McEGRPrV5j_duFxID6dWMWuZPL-exffkYSTWmZCMODB9mu1AFXgXs6xkoevX',
#                           'width': 3120}],
#               'place_id': 'ChIJSWwbbKJDfDkR3tWC779h6kU',
#               'reference': 'ChIJSWwbbKJDfDkR3tWC779h6kU',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'vicinity': '69PV+PG8, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2344571, 'lng': 77.3930707},
#                            'viewport': {'northeast': {'lat': 23.2357756302915,
#                                                       'lng': 77.3944031802915},
#                                         'southwest': {'lat': 23.23307766970849,
#                                                       'lng': 77.39170521970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': 'Nagar Palika Nigam Bhopal Vyayam Shala',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJmxPU1btCfDkRkjqt4MOMHHc',
#               'plus_code': {'compound_code': '69MV+Q6 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69MV+Q6'},
#               'rating': 5,
#               'reference': 'ChIJmxPU1btCfDkRkjqt4MOMHHc',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Ward No.27, Bhadbhada Road, Jawahar Chowk, North TT '
#                           'Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2415029, 'lng': 77.3947378},
#                            'viewport': {'northeast': {'lat': 23.2430456802915,
#                                                       'lng': 77.3962041802915},
#                                         'southwest': {'lat': 23.2403477197085,
#                                                       'lng': 77.3935062197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'NITTTR Gym',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 3120,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111620247023005079484">Ravikant '
#                                                 'Singh</a>'],
#                           'photo_reference': 'Aap_uEBQJ3CdJcONcLAzlKoMCBjbWJEyLjfmLVLYE0eXVCHu87BBhmnoesFHGdgCAYsjfxCtvqSZw5PSsjReHc4RFaYv7Pr1K64LEAkuQO0Q6Bi1TDa0aeK6RYIdVHU0iHXDCWg7qeOsF53Ll24d_yoJAtU7XogajiuEnh0K1Z5tE6iajXjF',
#                           'width': 4160}],
#               'place_id': 'ChIJzWfJmaRCfDkRe1IcFvsM_74',
#               'plus_code': {'compound_code': '69RV+JV Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69RV+JV'},
#               'rating': 4,
#               'reference': 'ChIJzWfJmaRCfDkRe1IcFvsM_74',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 23,
#               'vicinity': '462002, Rustam Ahaata Khan, Shymala Hills Slums, '
#                           'Shymala Hills, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2307354,
#                                         'lng': 77.39380129999999},
#                            'viewport': {'northeast': {'lat': 23.2320495302915,
#                                                       'lng': 77.3951906302915},
#                                         'southwest': {'lat': 23.2293515697085,
#                                                       'lng': 77.39249266970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Bablu Fitnees Club And Slimming Centre',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2322,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117820837794348005536">suryakant '
#                                                 'pandey</a>'],
#                           'photo_reference': 'Aap_uECGDft0G8qUQ49iX_wu6UeSgnzlAOPc_yDsMpKEphcTALOyJNW4z9S-_rUz_hpyL5S7UBTrZLtxw2sfPLKBE8IJ8HrFCcvwSGB6buel1U_qHuDsfE7P_bTQQTAuiV-rO8joYtePEGxpxrX5KFq9DvcW_aLsk_UH9DbITC7oyLLg5_08',
#                           'width': 4128}],
#               'place_id': 'ChIJtUD95bhCfDkRO-qQxZUspEg',
#               'plus_code': {'compound_code': '69JV+7G Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69JV+7G'},
#               'rating': 4,
#               'reference': 'ChIJtUD95bhCfDkRO-qQxZUspEg',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 22,
#               'vicinity': 'Top Floor, Galery Tower, Bhadbhada Road, Jawahar '
#                           'Chowk, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2456417, 'lng': 77.4071745},
#                            'viewport': {'northeast': {'lat': 23.2469649802915,
#                                                       'lng': 77.40855438029149},
#                                         'southwest': {'lat': 23.2442670197085,
#                                                       'lng': 77.40585641970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Pioneer water sport and welfare society',
#               'place_id': 'ChIJS0gbFz5DfDkRfmsfh5ob34Q',
#               'plus_code': {'compound_code': '6CW4+7V Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CW4+7V'},
#               'reference': 'ChIJS0gbFz5DfDkRfmsfh5ob34Q',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'vicinity': 'Minto Hall Road, Jahangirabad, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.226895,
#                                         'lng': 77.40995330000001},
#                            'viewport': {'northeast': {'lat': 23.2281435302915,
#                                                       'lng': 77.41143483029151},
#                                         'southwest': {'lat': 23.22544556970849,
#                                                       'lng': 77.4087368697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'म प्र प्रशासनिक सेवा संघ आकांशा',
#               'photos': [{'height': 3120,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103324617646435029940">The '
#                                                 'Raghav Singh</a>'],
#                           'photo_reference': 'Aap_uECwx4ZEWbuaUH3o5YSV3ryr-o4xNL2G1ef8znjqah9RkQ0IPulOhH8WzBigPSnnKj-yCIzucAYsrTTRIkHNwLrR-KoKADgDIBRHcNM3d12PdDpOsuOA2fNjUrXXnpXBZw5rV78jY3h5HvsK2ofLmF8gS_sy-aaWmG79TEnHeITtwo8Q',
#                           'width': 4160}],
#               'place_id': 'ChIJ884BAO1CfDkR40qCSmuC_EI',
#               'plus_code': {'compound_code': '6CG5+QX Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CG5+QX'},
#               'rating': 4,
#               'reference': 'ChIJ884BAO1CfDkR40qCSmuC_EI',
#               'scope': 'GOOGLE',
#               'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Shivaji Nagar, Bhopal'}],
#  'status': 'OK'}

# %%
results_lodgings = gmaps.places_nearby(location = "23.23577616704816, 77.40268416994763", radius=15000, type=['lodging'])
pprint.pprint(results_lodgings)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAzSD2YZ6EavBb1VoKN-ypsiaB0cTyO32E4G78jGpAH1O2emkEJmNZ66L-vpu61TU9j9EZhVZfMd-QyaFcwyoe1G0rRIGmQy69mF6vciIB4JjdGSr25piQNg5HVqTUChTZ1c8jTC3bMfcOjsI2i6kbxWbbBcxGZXJAPT6zxq2mtcHqLprr9dqdGez5zsAbVyUw0J5a0kZqTWrw3KpLw1gW7NY41CWFwgxyVBoCH2aaUi258yIX2vgD1zthyzJG6xastv1XC4ynlXB1bMe2orxB5rn3oRwcWicnTq31oV324JTmJwKaxNO7GiZgZfGd0_Pb62VFvkoIxjFjafFuxNULGC9mPgiVFqtY9xVOt5-qlDEsgApCL-ziuicR6K2uyeoKjzl8oORZ8bGrqRUPCRyuZ7w34BZND9CfOmFOG2HsnBdvOIcqsb9TL',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2405428, 'lng': 77.3872233},
#                            'viewport': {'northeast': {'lat': 23.2419047802915,
#                                                       'lng': 77.3886727302915},
#                                         'southwest': {'lat': 23.2392068197085,
#                                                       'lng': 77.38597476970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Jehan Numa Palace Hotel',
#               'photos': [{'height': 768,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109106485844928332557">Jehan '
#                                                 'Numa Palace Hotel</a>'],
#                           'photo_reference': 'Aap_uEBU9ydysyrilYOvoCHZn60-W1CQQZhZpOCVEANZSlm-s7R_lnFp-y9yWy8N7vg89pnkQhS0HnW-j9dnRxbjZ0UJ-_OfEGGcALmxOyG1icVjCebkwEvjB3qQfoy3S0PMtNQJ17A88u3aJ9vbBelfccCy1ivCUJsx5QhvOAb1Z_9lFrEg',
#                           'width': 1280}],
#               'place_id': 'ChIJq1vvMa5CfDkRo3X_8kWkqyI',
#               'plus_code': {'compound_code': '69RP+6V Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69RP+6V'},
#               'rating': 4.5,
#               'reference': 'ChIJq1vvMa5CfDkRo3X_8kWkqyI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 8102,
#               'vicinity': '157, Shyamla Hills Road, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.237078,
#                                         'lng': 77.40135160000001},
#                            'viewport': {'northeast': {'lat': 23.2384288802915,
#                                                       'lng': 77.40268878029151},
#                                         'southwest': {'lat': 23.23573091970849,
#                                                       'lng': 77.3999908197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'OYO Rooms 094 New Market',
#               'photos': [{'height': 3120,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110089982583150840050">vikram '
#                                                 'thawani</a>'],
#                           'photo_reference': 'Aap_uED9EGL5y4_c9aCcHR7s5MBH1YnXMoefq2tqGDeJZGy-Ju0LOE57djMiqmeo4FRuUXadV1NcYAiyIvaJL1sURxU_g4c_PeEa3yNqzqkzHN7UiBMNj7D_CZOwotvMrdx9PwniMGY5SSmT9D40pQSL7m45YrKi_g39TWnss1cZA79_ABGP',
#                           'width': 4160}],
#               'place_id': 'ChIJi50ZiL1CfDkR4NRjELw2kqc',
#               'plus_code': {'compound_code': '6CP2+RG Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP2+RG'},
#               'rating': 4,
#               'reference': 'ChIJi50ZiL1CfDkR4NRjELw2kqc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '84, New Market Main Road, Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2368781, 'lng': 77.4027302},
#                            'viewport': {'northeast': {'lat': 23.2382502302915,
#                                                       'lng': 77.40403568029151},
#                                         'southwest': {'lat': 23.2355522697085,
#                                                       'lng': 77.4013377197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'OYO Rooms Bhopal Malviya Nagar New Market',
#               'photos': [{'height': 5344,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101508260618207728968">NAUMAN '
#                                                 'KHAN</a>'],
#                           'photo_reference': 'Aap_uEDR60-AJ1lh8TC2aStkcpNQi28oXC0ua7KtuPFAhDQnKvsMW6aBDp_nijlE4fmt6V7ko-z3RrJXzugjOwap8yaqcOYnWaJMwRGm8ckGpEYg0JdVgt_xPb1U_mcF4S6Ex5XWwxMcDTugIsgCRc39IfbT5_lvd-XRxQXIAz0o0iMgIGSf',
#                           'width': 3006}],
#               'place_id': 'ChIJB-dTP5ZCfDkRoNVYLuMjz8A',
#               'plus_code': {'compound_code': '6CP3+Q3 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP3+Q3'},
#               'rating': 3.6,
#               'reference': 'ChIJB-dTP5ZCfDkRoNVYLuMjz8A',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 7,
#               'vicinity': 'Malviya Shopping Center, 27-B, Roshanpura Road, '
#                           'Near Ratrakar Bhawan,Near Patrakar Bhawan, New '
#                           'Market, Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2333743, 'lng': 77.4111394},
#                            'viewport': {'northeast': {'lat': 23.2347049802915,
#                                                       'lng': 77.4126216302915},
#                                         'southwest': {'lat': 23.2320070197085,
#                                                       'lng': 77.40992366970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Shree Vinayak Palace',
#               'place_id': 'ChIJ-44VhphCfDkReA5nJ_R2rp0',
#               'plus_code': {'compound_code': '6CM6+8F Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM6+8F'},
#               'reference': 'ChIJ-44VhphCfDkReA5nJ_R2rp0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'R-37, M.P Nagar Zone 2 Near sankalp netralay'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2373929, 'lng': 77.4014926},
#                            'viewport': {'northeast': {'lat': 23.2387578302915,
#                                                       'lng': 77.40280158029151},
#                                         'southwest': {'lat': 23.2360598697085,
#                                                       'lng': 77.4001036197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Pisals',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1483,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103973524423266271896">Prasad '
#                                                 'Kothari</a>'],
#                           'photo_reference': 'Aap_uECLKB74IW8U_kLAveeJr-ij2VfmOb5TntOj71G9sjau0q9vqN4P5EDCu7ZfDhPOPFIQglybLwq0WPDMouo-ZnaEp7fcA9e5j6bxkpuaibHbXSdya4uBb5U1Y0taQKAF1ZC-_KgxKAjPbZX6wJkH26fUUOZlC3ihZ4LkEP_Y_S9YDta-',
#                           'width': 1384}],
#               'place_id': 'ChIJOUZz5r1CfDkRpgpb_baUKIQ',
#               'plus_code': {'compound_code': '6CP2+XH Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP2+XH'},
#               'rating': 3.5,
#               'reference': 'ChIJOUZz5r1CfDkRpgpb_baUKIQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 167,
#               'vicinity': '29 New Market, Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2352135,
#                                         'lng': 77.39972159999999},
#                            'viewport': {'northeast': {'lat': 23.2365541302915,
#                                                       'lng': 77.4010554802915},
#                                         'southwest': {'lat': 23.2338561697085,
#                                                       'lng': 77.3983575197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'OYO 24097 Hotel Gangotri',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 427,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118056150098824009543">OYO '
#                                                 '24097 Hotel Gangotri</a>'],
#                           'photo_reference': 'Aap_uEA1l1-hXpWLLYF-MIVLA5rY2bjQ1MYBUKKlOSiC22L4DEciOyzJzyd1gXYvJi-uvRQ2YXOYbEWtsYvHCSpdC9b_KxsznTZnMxRtT_fBQR-FB0kDcrvTmKfrWzGDENPCL9xMSOFkjCwR90b5QCtMglUMmjp_-gLTBYqIQVNt3q1zRPo',
#                           'width': 640}],
#               'place_id': 'ChIJzyD1DyddfDkRD0WckXbjY0c',
#               'plus_code': {'compound_code': '69PX+3V Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69PX+3V'},
#               'price_level': 2,
#               'rating': 3.3,
#               'reference': 'ChIJzyD1DyddfDkRD0WckXbjY0c',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 181,
#               'vicinity': 'near Sakshi Dhaba, 4 Bhadbhada Road New Kerva '
#                           'Tiraha, near Sakshi Dhaba, Bhadbhada, Kopal, '
#                           'Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2335186,
#                                         'lng': 77.40326689999999},
#                            'viewport': {'northeast': {'lat': 23.2348359802915,
#                                                       'lng': 77.40457368029149},
#                                         'southwest': {'lat': 23.2321380197085,
#                                                       'lng': 77.40187571970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Saral Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 716,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102772631054723813835">Saral '
#                                                 'Hotel</a>'],
#                           'photo_reference': 'Aap_uECjZHRg7H-4wysNvxWw0ACXO6UYNoNyH4CS2VXKRkj5DgYpZJ5g09gJiX3z0vChZrXL3rrj7h4LZ04jwFXbHlI9mYiWHVThINXtSSDqd7enWrVi-Fl1EoyB8b9zX3kH7K-jMX8IeZ188Dz1ypaORZtS2ulYmYNik5to3jn_LqTccppY',
#                           'width': 386}],
#               'place_id': 'ChIJb1VVqZdCfDkRGMP9ppHLGYA',
#               'plus_code': {'compound_code': '6CM3+C8 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM3+C8'},
#               'rating': 3.5,
#               'reference': 'ChIJb1VVqZdCfDkRGMP9ppHLGYA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 149,
#               'vicinity': '47-B, Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2371288, 'lng': 77.4025123},
#                            'viewport': {'northeast': {'lat': 23.2385070302915,
#                                                       'lng': 77.40389773029149},
#                                         'southwest': {'lat': 23.2358090697085,
#                                                       'lng': 77.40119976970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Shree Palace Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1818,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113519783833588397491">Jaya '
#                                                 'Sharma</a>'],
#                           'photo_reference': 'Aap_uEBORdRzdc75fKaHOhSDdVAm_Z3owYLTeL026zdYvzEbbptZmqhcpc8NR2GD3AMlRGi8ESswGnl51AcEQ6hH0VK7N3UiOYNFuI3WVkFODYw_oaOiSchAJ0KKt6m6Jz1F8cSLYWC6mNidJmI6szLanhHuIcW545IHP93m14BcH2N_PBZ2',
#                           'width': 2398}],
#               'place_id': 'ChIJOeOaOZZCfDkRnAWWAP5HG80',
#               'plus_code': {'compound_code': '6CP3+V2 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP3+V2'},
#               'rating': 4.1,
#               'reference': 'ChIJOeOaOZZCfDkRnAWWAP5HG80',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 557,
#               'vicinity': 'Patrakar Bhavan, 135, Roshanpura Road, New Market, '
#                           'Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2349364, 'lng': 77.3989799},
#                            'viewport': {'northeast': {'lat': 23.2363691302915,
#                                                       'lng': 77.4004726302915},
#                                         'southwest': {'lat': 23.2336711697085,
#                                                       'lng': 77.3977746697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Park Hotel',
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112261654152398415921">Civilian '
#                                                 'Singh</a>'],
#                           'photo_reference': 'Aap_uEDO6ocz6dO10S_R-1YRk5ankYzlpMoCbA0D_9Fe1jDckE_Sfdst6CVOBW_65ESOLkTBR3q8S87TkEmtHTEuSmVYVDu2lnKZaxaMYu7kBxgC6EJESmscyHSiPg2RB8heLAhxDVZX8nbrOP_Npwyynu2dCpEQLYkhmtItUdvAUwvxcxZL',
#                           'width': 4608}],
#               'place_id': 'ChIJ_____7hCfDkRZmVtrnCCWqo',
#               'plus_code': {'compound_code': '69MX+XH Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69MX+XH'},
#               'rating': 3.9,
#               'reference': 'ChIJ_____7hCfDkRZmVtrnCCWqo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 118,
#               'vicinity': 'Rang Mahal Tower Bhadbhada Rd, New Market, TT '
#                           'Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.234855,
#                                         'lng': 77.40223399999999},
#                            'viewport': {'northeast': {'lat': 23.2361403802915,
#                                                       'lng': 77.4034984802915},
#                                         'southwest': {'lat': 23.2334424197085,
#                                                       'lng': 77.40080051970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Sarthak',
#               'photos': [{'height': 3456,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105397366057466459009">Hitesh '
#                                                 'Bhatnagar</a>'],
#                           'photo_reference': 'Aap_uEAPp7oNnFFnDs-5mEoKv-Y6nO5vf85o9GJjH86EbWsb8end5bF_rEgouVSZ-aV9SGGmTm8aWiZAFTJSgf0tw7J6bXc8lgPaNvE90XORQgzc2eAIy0qo8VlISVUcD2qXiaP34hsaX9qR4SpFTQbc0ra3Xr04fMHfrTNFjwhbKqjBGZ72',
#                           'width': 4608}],
#               'place_id': 'ChIJib3B4pVCfDkRx5uggBhOTYY',
#               'plus_code': {'compound_code': '6CM2+WV Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CM2+WV'},
#               'rating': 4,
#               'reference': 'ChIJib3B4pVCfDkRx5uggBhOTYY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 980,
#               'vicinity': '37 Opp. Indian Coffee House, New Market, Malviya '
#                           'Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2364083, 'lng': 77.4014396},
#                            'viewport': {'northeast': {'lat': 23.2377546302915,
#                                                       'lng': 77.40274458029153},
#                                         'southwest': {'lat': 23.2350566697085,
#                                                       'lng': 77.4000466197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Brij Palace',
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104108301467828154457">Prasang '
#                                                 'Singh Parihar</a>'],
#                           'photo_reference': 'Aap_uEDs5B6Yhv4th3LjyoH3lHS_lFlB0L0sk1cp4f0lsyTwoqQQZH4XT9fNQ1DTTyJamEMZn8aCM20Fyw8e-dOZ8VMOIvcZjimftIfYE9f-3nKXZInDm25N74he4M076jT9yZk5BW77GyjawXLNbN0kK3Is4c_GZi1-1d02iiFSksaGRrz-',
#                           'width': 2048}],
#               'place_id': 'ChIJF6gtHpZCfDkRXhLGMRje3FY',
#               'plus_code': {'compound_code': '6CP2+HH Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP2+HH'},
#               'rating': 3.8,
#               'reference': 'ChIJF6gtHpZCfDkRXhLGMRje3FY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 160,
#               'vicinity': '69, Malviya Nagar, New Market Main Road, New '
#                           'Market, STT Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2371624,
#                                         'lng': 77.40350839999999},
#                            'viewport': {'northeast': {'lat': 23.23862363029151,
#                                                       'lng': 77.4047742802915},
#                                         'southwest': {'lat': 23.2359256697085,
#                                                       'lng': 77.40207631970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'OYO 751 Hotel Shree Palace',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 428,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107120326958766211830">OYO '
#                                                 '751 Hotel Shree Palace</a>'],
#                           'photo_reference': 'Aap_uEAvsr9hMHlufZW8BVqj8HGfJAdB6HqmNfvFVE3NNbPAH1kiyftuCimqTLmYltaRq2Q1Cxd1iKbDKySze7WSpGISKIi5oDF_aO4l0DuPIIaYwBQn8PfwNHgNozR44wNrSuJewoxI4HerzXyFh4963O7eGpUIUTJzKwv3DZDrvsKq6UbE',
#                           'width': 761}],
#               'place_id': 'ChIJBYQkRZZCfDkRrN89GT28aYs',
#               'plus_code': {'compound_code': '6CP3+VC Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP3+VC'},
#               'rating': 1,
#               'reference': 'ChIJBYQkRZZCfDkRrN89GT28aYs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '135, Patrakar Bhavan, Kamla Park Road, New Market, '
#                           'Malviya Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2356348, 'lng': 77.4006283},
#                            'viewport': {'northeast': {'lat': 23.2369869802915,
#                                                       'lng': 77.40197698029151},
#                                         'southwest': {'lat': 23.2342890197085,
#                                                       'lng': 77.39927901970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel QiK Stay at Crown Palace',
#               'place_id': 'ChIJHaKq-r1CfDkR9vREzmgsqmI',
#               'plus_code': {'compound_code': '6CP2+77 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CP2+77'},
#               'rating': 5,
#               'reference': 'ChIJHaKq-r1CfDkR9vREzmgsqmI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '2/36, Bhadbhada Road, New Market, STT Nagar, TT '
#                           'Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2434656, 'lng': 77.4069756},
#                            'viewport': {'northeast': {'lat': 23.2448969302915,
#                                                       'lng': 77.40832668029151},
#                                         'southwest': {'lat': 23.2421989697085,
#                                                       'lng': 77.40562871970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Kushabhau Thakre Hall',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106185574256063720085">Prasanna '
#                                                 'Jagdale</a>'],
#                           'photo_reference': 'Aap_uEDN_74aQiET9ravukieLEuWoj9LZ2LiZsWLtCYhQjxdUQt3gGRtqZOEs2wPV0EJg_rSMR-vi7ENS33WSZWnpGAZVsVd8VknyFIo9YbxY42IyIT8_QnSNOt1TrO9K8jDbyXiGPiw4VICLp8vgLkkgzHsyUbBLtj2hF363L3ubyQMLUA5',
#                           'width': 6240}],
#               'place_id': 'ChIJweoMOZpCfDkRFK8Y-1wd52s',
#               'plus_code': {'compound_code': '6CV4+9Q Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV6CV4+9Q'},
#               'price_level': 4,
#               'rating': 4.5,
#               'reference': 'ChIJweoMOZpCfDkRFK8Y-1wd52s',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1637,
#               'vicinity': 'opp. Governor House, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2365377,
#                                         'lng': 77.39252359999999},
#                            'viewport': {'northeast': {'lat': 23.2378660302915,
#                                                       'lng': 77.3939191802915},
#                                         'southwest': {'lat': 23.2351680697085,
#                                                       'lng': 77.3912212197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'royal building',
#               'place_id': 'ChIJ9exdUrpCfDkR-gpAM7loek0',
#               'plus_code': {'compound_code': '69PV+J2 Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69PV+J2'},
#               'rating': 3.7,
#               'reference': 'ChIJ9exdUrpCfDkR-gpAM7loek0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 6,
#               'vicinity': '26/9, New Dushera Maidan, Banganga Slums, North TT '
#                           'Nagar, TT Nagar, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2455666, 'lng': 77.3989261},
#                            'viewport': {'northeast': {'lat': 23.2470985802915,
#                                                       'lng': 77.4002791802915},
#                                         'southwest': {'lat': 23.2444006197085,
#                                                       'lng': 77.39758121970848}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': 'Vishram Grah',
#               'photos': [{'height': 900,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106733310905003050074">Kamaal '
#                                                 'Ahmed</a>'],
#                           'photo_reference': 'Aap_uECtrLxsmM3lstQbym_pMVwGGIFYRzT16N5LvODIGoyWQYL9JqrQk_mIwRPsWMAUUsVlJwSFz7z2mMmpXa1UqK8tE_BrWcKbjf2COrypT0-qO7gpyiWF_48wCvu7L9E_r2uFMjMkXJpq14uJzF3i_BBQdqzO0ph-qIUBY011Zc6fkMIM',
#                           'width': 720}],
#               'place_id': 'ChIJ0ytE9qJCfDkRi8fX6nhR4p4',
#               'plus_code': {'compound_code': '69WX+6H Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69WX+6H'},
#               'rating': 4.1,
#               'reference': 'ChIJ0ytE9qJCfDkRi8fX6nhR4p4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 17,
#               'vicinity': 'Kamla Park Road, Sardar Vallabh Bhai Patel '
#                           'Polytechnic Chouraha, Professors Colony, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2480053,
#                                         'lng': 77.39903650000001},
#                            'viewport': {'northeast': {'lat': 23.2493709802915,
#                                                       'lng': 77.40034378029151},
#                                         'southwest': {'lat': 23.2466730197085,
#                                                       'lng': 77.3976458197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Leela Heights',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104948173741943004722">Saad '
#                                                 'Bin Waqqas</a>'],
#                           'photo_reference': 'Aap_uECcHl4TtsZZ9Q4zbkVjQ-6WnWc7EiQr0AmkIFhDjDQd5qR4yPI4hCkRLZ2RdHISWQFcKJnn3LPs-UXuiIK_Zwt9sFGaRMRzBplmqX6xlkRNabZV0yDOahFfJGWWlsbZNURDAtrGoaSYa8ijOZORECyJhhChQZ8fukhQZplIKNhw0ryx',
#                           'width': 1920}],
#               'place_id': 'ChIJ4wZ4mKFCfDkRMYmHCtB7jQs',
#               'plus_code': {'compound_code': '69XX+6J Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69XX+6J'},
#               'rating': 4.1,
#               'reference': 'ChIJ4wZ4mKFCfDkRMYmHCtB7jQs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 68,
#               'vicinity': '10/3,Kamla Park Road, Civil Lines, Krishna Nagar, '
#                           'Professors Colony, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2491483,
#                                         'lng': 77.39433280000002},
#                            'viewport': {'northeast': {'lat': 23.2504421302915,
#                                                       'lng': 77.39574548029151},
#                                         'southwest': {'lat': 23.2477441697085,
#                                                       'lng': 77.39304751970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Lago Villa',
#               'photos': [{'height': 1868,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101524512913616355209">Dr '
#                                                 'Sachin Dalal</a>'],
#                           'photo_reference': 'Aap_uEB4j3eYZbymV3dsg0Nmqgdkgh8ERBqW7iqX9NJBP_t6HX-GoPN2qmhQtQuIPwhR2vVfsFbyDAWr1A-nkervs7E70TyEpdM4PiS9d5VSRJ114MP8MZYcG_g_QpEUmZASpqjQYONjwWX5urcM9Fl_LhGQTD3aahrM9nSbbre9uIcI3_pb',
#                           'width': 4000}],
#               'place_id': 'ChIJfVnYIadCfDkRZL0MmErAf5A',
#               'plus_code': {'compound_code': '69XV+MP Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69XV+MP'},
#               'rating': 4.3,
#               'reference': 'ChIJfVnYIadCfDkRZL0MmErAf5A',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 142,
#               'vicinity': '17 Shamla Road, Bharat Bhawan Road, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.24131,
#                                         'lng': 77.38615999999999},
#                            'viewport': {'northeast': {'lat': 23.2426955802915,
#                                                       'lng': 77.3874829302915},
#                                         'southwest': {'lat': 23.2399976197085,
#                                                       'lng': 77.38478496970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'OYO 5201 Metro Home Stay',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 428,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115128394268506713200">OYO '
#                                                 '5201 Metro Home Stay</a>'],
#                           'photo_reference': 'Aap_uEDzNA3JAw3IO81xCCb7lf-QNBNFZH6gzUOKCEObTed3f4rF2vK0b69jvaemxylZh4KLOcvUKrXdgkmFlHm2XmGqulZlIq9_a6RwJDq-bpxfaznhzhvQJuRgy-icH7bqwXm3JHWLqh6IFpbzmeHBu-WVZQmYbon_gF_mG_Mr-KT9nZRX',
#                           'width': 761}],
#               'place_id': 'ChIJjSpCRq5CfDkREIClvMQLvHk',
#               'plus_code': {'compound_code': '69RP+GF Bhopal, Madhya Pradesh, '
#                                              'India',
#                             'global_code': '7JMV69RP+GF'},
#               'rating': 3.5,
#               'reference': 'ChIJjSpCRq5CfDkREIClvMQLvHk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Plot No.18, Nishat Manzil, Shimla Hills, Bhopal'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 23.2370066, 'lng': 77.4085149},
#                            'viewport': {'northeast': {'lat': 23.2386369302915,
#                                                       'lng': 77.4096049802915},
#                                         'southwest': {'lat': 23.2359389697085,
#                                                       'lng': 77.4069070197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Ellora Hotel',
#               'photos': [{'height': 2340,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115096693221780181879">Manisha '
#                                                 'Amit</a>'],
#                           'photo_reference': 'Aap_uED6pRCKsDIsurcY__okJXp0d4_xEwJ4QTmXnajTOeUF_QFO0q1floN_38yYzDEjZllEa99pDxbNkoNsrg6Ndpdzz0Asak4Fug1TkCKWRvVSAezrW4v6kfWt76a8EfySlA2KxtogkE0qJJ2O15AH2FjJ996BG85eJ-DNwii3xlZw8GQI',
#                           'width': 4160}],
#               'place_id': 'ChIJq6qqapFCfDkR_U6OQ9tSsIk',
#               'rating': 3.4,
#               'reference': 'ChIJq6qqapFCfDkR_U6OQ9tSsIk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 7,
#               'vicinity': 'behind ETV Office, 98, Zone-2, Opposite SBI Colony '
#                           'M.P. Nagar, behind ETV Office'}],
#  'status': 'OK'}

# %%
venues_food=pd.json_normalize(results_food['results'])
venues_food
# Out:
#        business_status                                               icon  \
# 0          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   CLOSED_TEMPORARILY  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   CLOSED_TEMPORARILY  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   CLOSED_TEMPORARILY  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#    icon_background_color                                 icon_mask_base_uri  \
# 0                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9                #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19               #FF9E67  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                     name  \
# 0      New Inn Restaurant & Coffee House
# 1   Café Coffee Day - Usha Preet Complex
# 2                          shasha's Cafe
# 3         Guddu Tea Stall And Restaurant
# 4                 Azamgarh (Azmi Palace)
# 5             Ambrosia Cafe & Restaurant
# 6                  Prince Jaljira Center
# 7                              Keventers
# 8                          Tandoori Chai
# 9                        Jyoti Tea Stall
# 10                    Bhopali chai sutta
# 11                Super tea coffee stall
# 12                     Milkshake Kulture
# 13                      DIET DESSERT CO.
# 14                      Famous Soda Shop
# 15       KULHADWAALA (DESI CHAI KA ADDA)
# 16                   The Smokin'Shawarma
# 17                         Ali Tea Stall
# 18                          Bake-n-shake
# 19                Teafriend's New Market
#
#                                                photos  \
# 0   [{'height': 2610, 'html_attributions': ['<a hr...
# 1   [{'height': 774, 'html_attributions': ['<a hre...
# 2                                                 NaN
# 3   [{'height': 1920, 'html_attributions': ['<a hr...
# 4   [{'height': 1757, 'html_attributions': ['<a hr...
# 5   [{'height': 323, 'html_attributions': ['<a hre...
# 6   [{'height': 801, 'html_attributions': ['<a hre...
# 7   [{'height': 2064, 'html_attributions': ['<a hr...
# 8   [{'height': 3120, 'html_attributions': ['<a hr...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  [{'height': 3120, 'html_attributions': ['<a hr...
# 13  [{'height': 590, 'html_attributions': ['<a hre...
# 14  [{'height': 3456, 'html_attributions': ['<a hr...
# 15  [{'height': 405, 'html_attributions': ['<a hre...
# 16  [{'height': 4032, 'html_attributions': ['<a hr...
# 17                                                NaN
# 18  [{'height': 1952, 'html_attributions': ['<a hr...
# 19  [{'height': 4160, 'html_attributions': ['<a hr...
#
#                        place_id  price_level  rating  \
# 0   ChIJKQovNLlCfDkR2X4kQjn5ys8          2.0     3.7
# 1   ChIJyZqdspVCfDkR6YL3ElvMdcI          2.0     4.1
# 2   ChIJeUp3f8dCfDkRF8uLI1W-2NM          NaN     4.0
# 3   ChIJ-4c8b4RCfDkR9iJZc1K73pI          NaN     3.9
# 4   ChIJ5WA1f4NCfDkR5H7UZ_fh_XQ          NaN     4.0
# 5   ChIJMUoGB5ZCfDkR_jCAD3RXcKE          NaN     3.9
# 6   ChIJXf2Oz4hDfDkRWkk7htML9CM          NaN     3.7
# 7   ChIJ55q_Ab5CfDkRnyy3vXfan4c          2.0     4.3
# 8   ChIJ5WRghElDfDkRbjkUuTW8Vg0          NaN     5.0
# 9   ChIJmdbtM5ZCfDkRW0B2UYQPCvU          NaN     NaN
# 10  ChIJfZ6iHFFDfDkRS0Wxh4LZbro          NaN     NaN
# 11  ChIJY7esCC1DfDkR7WlZVpzlojs          NaN     5.0
# 12  ChIJkZCCTJRCfDkRXBqhzIBhXsg          2.0     4.1
# 13  ChIJAVQT4h9DfDkR4rKOgILG7M8          NaN     5.0
# 14  ChIJB8oFn71CfDkRUWinsqE75xI          NaN     5.0
# 15  ChIJjW4uoyRDfDkRrPIr28rMpc8          NaN     1.0
# 16  ChIJK_nH2PJDfDkRDsq2AJo4ej4          NaN     NaN
# 17  ChIJQ-U9Zb1CfDkRzk6QwKWqj8k          NaN     NaN
# 18  ChIJLYST1r1CfDkRlqlZd50lyWQ          2.0     4.3
# 19  ChIJE-Dgf75CfDkRHMn_GDEeEks          NaN     4.2
#
#                       reference  ... geometry.location.lat  \
# 0   ChIJKQovNLlCfDkR2X4kQjn5ys8  ...             23.236551
# 1   ChIJyZqdspVCfDkR6YL3ElvMdcI  ...             23.234065
# 2   ChIJeUp3f8dCfDkRF8uLI1W-2NM  ...             23.228191
# 3   ChIJ-4c8b4RCfDkR9iJZc1K73pI  ...             23.246871
# 4   ChIJ5WA1f4NCfDkR5H7UZ_fh_XQ  ...             23.248258
# 5   ChIJMUoGB5ZCfDkR_jCAD3RXcKE  ...             23.235122
# 6   ChIJXf2Oz4hDfDkRWkk7htML9CM  ...             23.234712
# 7   ChIJ55q_Ab5CfDkRnyy3vXfan4c  ...             23.234690
# 8   ChIJ5WRghElDfDkRbjkUuTW8Vg0  ...             23.235636
# 9   ChIJmdbtM5ZCfDkRW0B2UYQPCvU  ...             23.237675
# 10  ChIJfZ6iHFFDfDkRS0Wxh4LZbro  ...             23.238082
# 11  ChIJY7esCC1DfDkR7WlZVpzlojs  ...             23.234591
# 12  ChIJkZCCTJRCfDkRXBqhzIBhXsg  ...             23.233407
# 13  ChIJAVQT4h9DfDkR4rKOgILG7M8  ...             23.233419
# 14  ChIJB8oFn71CfDkRUWinsqE75xI  ...             23.237028
# 15  ChIJjW4uoyRDfDkRrPIr28rMpc8  ...             23.236797
# 16  ChIJK_nH2PJDfDkRDsq2AJo4ej4  ...             23.236254
# 17  ChIJQ-U9Zb1CfDkRzk6QwKWqj8k  ...             23.238659
# 18  ChIJLYST1r1CfDkRlqlZd50lyWQ  ...             23.234999
# 19  ChIJE-Dgf75CfDkRHMn_GDEeEks  ...             23.234651
#
#    geometry.location.lng  geometry.viewport.northeast.lat  \
# 0              77.400195                        23.237946
# 1              77.402762                        23.235387
# 2              77.392808                        23.229607
# 3              77.416530                        23.248217
# 4              77.415537                        23.249607
# 5              77.401921                        23.236424
# 6              77.401619                        23.236055
# 7              77.401247                        23.235755
# 8              77.400623                        23.236987
# 9              77.402362                        23.239239
# 10             77.401833                        23.239459
# 11             77.400284                        23.235919
# 12             77.404288                        23.234730
# 13             77.404342                        23.234729
# 14             77.399886                        23.238375
# 15             77.399224                        23.238173
# 16             77.399067                        23.237572
# 17             77.400738                        23.239980
# 18             77.398901                        23.236538
# 19             77.398487                        23.236185
#
#    geometry.viewport.northeast.lng  geometry.viewport.southwest.lat  \
# 0                        77.401501                        23.235248
# 1                        77.404074                        23.232689
# 2                        77.394067                        23.226909
# 3                        77.417873                        23.245519
# 4                        77.416889                        23.246909
# 5                        77.403208                        23.233726
# 6                        77.402889                        23.233357
# 7                        77.402572                        23.233057
# 8                        77.401972                        23.234289
# 9                        77.403523                        23.236541
# 10                       77.403159                        23.236761
# 11                       77.401634                        23.233221
# 12                       77.405603                        23.232033
# 13                       77.405636                        23.232031
# 14                       77.401237                        23.235677
# 15                       77.400548                        23.235475
# 16                       77.400446                        23.234874
# 17                       77.402045                        23.237282
# 18                       77.400073                        23.233840
# 19                       77.399640                        23.233487
#
#     geometry.viewport.southwest.lng  opening_hours.open_now  \
# 0                         77.398803                   False
# 1                         77.401376                     NaN
# 2                         77.391369                   False
# 3                         77.415175                   False
# 4                         77.414191                    True
# 5                         77.400510                   False
# 6                         77.400191                   False
# 7                         77.399874                     NaN
# 8                         77.399274                   False
# 9                         77.400825                     NaN
# 10                        77.400462                     NaN
# 11                        77.398936                     NaN
# 12                        77.402905                   False
# 13                        77.402938                   False
# 14                        77.398539                   False
# 15                        77.397850                   False
# 16                        77.397748                     NaN
# 17                        77.399347                     NaN
# 18                        77.397375                   False
# 19                        77.396942                   False
#
#                   plus_code.compound_code  plus_code.global_code  \
# 0   6CP2+J3 Bhopal, Madhya Pradesh, India            7JMV6CP2+J3
# 1   6CM3+J4 Bhopal, Madhya Pradesh, India            7JMV6CM3+J4
# 2   69HV+74 Bhopal, Madhya Pradesh, India            7JMV69HV+74
# 3   6CW8+PJ Bhopal, Madhya Pradesh, India            7JMV6CW8+PJ
# 4   6CX8+86 Bhopal, Madhya Pradesh, India            7JMV6CX8+86
# 5   6CP2+2Q Bhopal, Madhya Pradesh, India            7JMV6CP2+2Q
# 6   6CM2+VJ Bhopal, Madhya Pradesh, India            7JMV6CM2+VJ
# 7   6CM2+VF Bhopal, Madhya Pradesh, India            7JMV6CM2+VF
# 8   6CP2+76 Bhopal, Madhya Pradesh, India            7JMV6CP2+76
# 9   6CQ2+3W Bhopal, Madhya Pradesh, India            7JMV6CQ2+3W
# 10  6CQ2+6P Bhopal, Madhya Pradesh, India            7JMV6CQ2+6P
# 11  6CM2+R4 Bhopal, Madhya Pradesh, India            7JMV6CM2+R4
# 12  6CM3+9P Bhopal, Madhya Pradesh, India            7JMV6CM3+9P
# 13  6CM3+9P Bhopal, Madhya Pradesh, India            7JMV6CM3+9P
# 14  69PX+RX Bhopal, Madhya Pradesh, India            7JMV69PX+RX
# 15  69PX+PM Bhopal, Madhya Pradesh, India            7JMV69PX+PM
# 16  69PX+GJ Bhopal, Madhya Pradesh, India            7JMV69PX+GJ
# 17                                    NaN                    NaN
# 18  69MX+XH Bhopal, Madhya Pradesh, India            7JMV69MX+XH
# 19  69MX+V9 Bhopal, Madhya Pradesh, India            7JMV69MX+V9
#
#     permanently_closed
# 0                  NaN
# 1                 True
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                 True
# 8                  NaN
# 9                 True
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
#
# [20 rows x 24 columns]

# %%
venues_gym=pd.json_normalize(results_gym['results'])
venues_gym
# Out:
#        business_status                                               icon  \
# 0   CLOSED_TEMPORARILY  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9          OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19         OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#    icon_background_color                                 icon_mask_base_uri  \
# 0                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3                #F88181  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9                #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                  name permanently_closed  \
# 0                             U.S. Fitness Club & Gym               True
# 1                                      Vishal Fitness                NaN
# 2                                   Amway Distributor                NaN
# 3                          The Fitness World By C Max                NaN
# 4                               The Fitness World Gym                NaN
# 5                                        Essentia Spa                NaN
# 6                                        Akhil Sports                NaN
# 7   VLCC Wellness Center, (Malviya Nagar, New Mark...                NaN
# 8                         STAY HEALTHY AND FIT CENTER                NaN
# 9                             Gymnasium (Body Temple)                NaN
# 10                                   Powermax Fitness                NaN
# 11                         Control Room And Reception                NaN
# 12                    he man gents parlour manoj umre                NaN
# 13                          The Mark Fitness Care Gym                NaN
# 14                                     Bhagvati Motor                NaN
# 15             Nagar Palika Nigam Bhopal Vyayam Shala                NaN
# 16                                         NITTTR Gym                NaN
# 17             Bablu Fitnees Club And Slimming Centre                NaN
# 18            Pioneer water sport and welfare society                NaN
# 19                    म प्र प्रशासनिक सेवा संघ आकांशा                NaN
#
#                        place_id  rating                    reference   scope  \
# 0   ChIJOcFFwupCfDkRqMU9QCvIVv4     3.4  ChIJOcFFwupCfDkRqMU9QCvIVv4  GOOGLE
# 1   ChIJp6pIpJJCfDkRnfDrCIjBGWE     4.3  ChIJp6pIpJJCfDkRnfDrCIjBGWE  GOOGLE
# 2   ChIJa7aHlLhCfDkRWx2JtUC8E-o     3.7  ChIJa7aHlLhCfDkRWx2JtUC8E-o  GOOGLE
# 3   ChIJUY0tUqRCfDkRnHRnJVdtkW0     5.0  ChIJUY0tUqRCfDkRnHRnJVdtkW0  GOOGLE
# 4   ChIJM5aSR6FCfDkRfpwTr4OLu2k     3.8  ChIJM5aSR6FCfDkRfpwTr4OLu2k  GOOGLE
# 5   ChIJWWacBq9CfDkRmRVpPEevKx8     NaN  ChIJWWacBq9CfDkRmRVpPEevKx8  GOOGLE
# 6   ChIJEUtB3gJDfDkR7JttKHLPX4M     4.0  ChIJEUtB3gJDfDkR7JttKHLPX4M  GOOGLE
# 7   ChIJ____q5dCfDkRS6xIGKXtseg     4.5  ChIJ____q5dCfDkRS6xIGKXtseg  GOOGLE
# 8   ChIJn4YJT5RCfDkRI6il6T2wgqg     5.0  ChIJn4YJT5RCfDkRI6il6T2wgqg  GOOGLE
# 9   ChIJDZ_hMrxCfDkRzYOkWpee1pQ     4.2  ChIJDZ_hMrxCfDkRzYOkWpee1pQ  GOOGLE
# 10  ChIJa310p9VDfDkR7fFg8TwuB4Q     1.0  ChIJa310p9VDfDkR7fFg8TwuB4Q  GOOGLE
# 11  ChIJiRK3r79CfDkRjxZyzrHQDEk     3.0  ChIJiRK3r79CfDkRjxZyzrHQDEk  GOOGLE
# 12  ChIJb13Ftr5CfDkR0YBtKYrPeUw     NaN  ChIJb13Ftr5CfDkR0YBtKYrPeUw  GOOGLE
# 13  ChIJs7jZErlCfDkRvzNfN6ljePs     4.3  ChIJs7jZErlCfDkRvzNfN6ljePs  GOOGLE
# 14  ChIJSWwbbKJDfDkR3tWC779h6kU     NaN  ChIJSWwbbKJDfDkR3tWC779h6kU  GOOGLE
# 15  ChIJmxPU1btCfDkRkjqt4MOMHHc     5.0  ChIJmxPU1btCfDkRkjqt4MOMHHc  GOOGLE
# 16  ChIJzWfJmaRCfDkRe1IcFvsM_74     4.0  ChIJzWfJmaRCfDkRe1IcFvsM_74  GOOGLE
# 17  ChIJtUD95bhCfDkRO-qQxZUspEg     4.0  ChIJtUD95bhCfDkRO-qQxZUspEg  GOOGLE
# 18  ChIJS0gbFz5DfDkRfmsfh5ob34Q     NaN  ChIJS0gbFz5DfDkRfmsfh5ob34Q  GOOGLE
# 19  ChIJ884BAO1CfDkR40qCSmuC_EI     4.0  ChIJ884BAO1CfDkR40qCSmuC_EI  GOOGLE
#
#     ... geometry.location.lat  geometry.location.lng  \
# 0   ...             23.227933              77.403255
# 1   ...             23.231111              77.411518
# 2   ...             23.229793              77.393845
# 3   ...             23.243630              77.393051
# 4   ...             23.247653              77.396430
# 5   ...             23.242963              77.387470
# 6   ...             23.235542              77.401278
# 7   ...             23.238316              77.401282
# 8   ...             23.233242              77.404814
# 9   ...             23.235625              77.398364
# 10  ...             23.239386              77.405268
# 11  ...             23.231269              77.399128
# 12  ...             23.233391              77.396088
# 13  ...             23.232663              77.394737
# 14  ...             23.236776              77.393839
# 15  ...             23.234457              77.393071
# 16  ...             23.241503              77.394738
# 17  ...             23.230735              77.393801
# 18  ...             23.245642              77.407174
# 19  ...             23.226895              77.409953
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        23.229292                        77.404705
# 1                        23.232461                        77.412865
# 2                        23.231144                        77.395198
# 3                        23.244996                        77.394421
# 4                        23.249051                        77.397874
# 5                        23.244263                        77.388909
# 6                        23.236891                        77.402627
# 7                        23.239715                        77.402746
# 8                        23.234598                        77.406163
# 9                        23.236901                        77.399787
# 10                       23.240778                        77.406583
# 11                       23.232616                        77.400393
# 12                       23.234755                        77.397423
# 13                       23.234020                        77.396098
# 14                       23.238116                        77.395210
# 15                       23.235776                        77.394403
# 16                       23.243046                        77.396204
# 17                       23.232050                        77.395191
# 18                       23.246965                        77.408554
# 19                       23.228144                        77.411435
#
#     geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                         23.226594                        77.402007
# 1                         23.229763                        77.410167
# 2                         23.228446                        77.392500
# 3                         23.242298                        77.391723
# 4                         23.246353                        77.395176
# 5                         23.241565                        77.386211
# 6                         23.234193                        77.399929
# 7                         23.237017                        77.400048
# 8                         23.231900                        77.403465
# 9                         23.234203                        77.397089
# 10                        23.238080                        77.403885
# 11                        23.229918                        77.397696
# 12                        23.232057                        77.394725
# 13                        23.231322                        77.393400
# 14                        23.235418                        77.392512
# 15                        23.233078                        77.391705
# 16                        23.240348                        77.393506
# 17                        23.229352                        77.392493
# 18                        23.244267                        77.405856
# 19                        23.225446                        77.408737
#
#                   plus_code.compound_code  plus_code.global_code  \
# 0   6CH3+58 Bhopal, Madhya Pradesh, India            7JMV6CH3+58
# 1   6CJ6+CJ Bhopal, Madhya Pradesh, India            7JMV6CJ6+CJ
# 2   69HV+WG Bhopal, Madhya Pradesh, India            7JMV69HV+WG
# 3   69VV+F6 Bhopal, Madhya Pradesh, India            7JMV69VV+F6
# 4   69XW+3H Bhopal, Madhya Pradesh, India            7JMV69XW+3H
# 5                                     NaN                    NaN
# 6   6CP2+6G Bhopal, Madhya Pradesh, India            7JMV6CP2+6G
# 7   6CQ2+8G Bhopal, Madhya Pradesh, India            7JMV6CQ2+8G
# 8   6CM3+7W Bhopal, Madhya Pradesh, India            7JMV6CM3+7W
# 9   69PX+78 Bhopal, Madhya Pradesh, India            7JMV69PX+78
# 10  6CQ4+Q4 Bhopal, Madhya Pradesh, India            7JMV6CQ4+Q4
# 11                                    NaN                    NaN
# 12                                    NaN                    NaN
# 13                                    NaN                    NaN
# 14                                    NaN                    NaN
# 15  69MV+Q6 Bhopal, Madhya Pradesh, India            7JMV69MV+Q6
# 16  69RV+JV Bhopal, Madhya Pradesh, India            7JMV69RV+JV
# 17  69JV+7G Bhopal, Madhya Pradesh, India            7JMV69JV+7G
# 18  6CW4+7V Bhopal, Madhya Pradesh, India            7JMV6CW4+7V
# 19  6CG5+QX Bhopal, Madhya Pradesh, India            7JMV6CG5+QX
#
#                                                photos opening_hours.open_now
# 0                                                 NaN                    NaN
# 1   [{'height': 2250, 'html_attributions': ['<a hr...                  False
# 2                                                 NaN                    NaN
# 3                                                 NaN                  False
# 4   [{'height': 4032, 'html_attributions': ['<a hr...                  False
# 5                                                 NaN                    NaN
# 6                                                 NaN                  False
# 7   [{'height': 1536, 'html_attributions': ['<a hr...                  False
# 8   [{'height': 2448, 'html_attributions': ['<a hr...                   True
# 9   [{'height': 536, 'html_attributions': ['<a hre...                  False
# 10  [{'height': 608, 'html_attributions': ['<a hre...                    NaN
# 11                                                NaN                    NaN
# 12                                                NaN                  False
# 13                                                NaN                  False
# 14  [{'height': 4160, 'html_attributions': ['<a hr...                  False
# 15                                                NaN                  False
# 16  [{'height': 3120, 'html_attributions': ['<a hr...                  False
# 17  [{'height': 2322, 'html_attributions': ['<a hr...                  False
# 18                                                NaN                    NaN
# 19  [{'height': 3120, 'html_attributions': ['<a hr...                    NaN
#
# [20 rows x 23 columns]

# %%
venues_lodg=pd.json_normalize(results_lodgings['results'])
venues_lodg
# Out:
#    business_status                                               icon  \
# 0      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9      OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19     OPERATIONAL  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#    icon_background_color                                 icon_mask_base_uri  \
# 0                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 5                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 6                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 7                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 8                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 9                #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 10               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15               #7B9EB0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19               #909CE1  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          name  \
# 0                     Jehan Numa Palace Hotel
# 1                    OYO Rooms 094 New Market
# 2   OYO Rooms Bhopal Malviya Nagar New Market
# 3                  Hotel Shree Vinayak Palace
# 4                                Hotel Pisals
# 5                    OYO 24097 Hotel Gangotri
# 6                                 Saral Hotel
# 7                          Shree Palace Hotel
# 8                                  Park Hotel
# 9                               Hotel Sarthak
# 10                          Hotel Brij Palace
# 11                 OYO 751 Hotel Shree Palace
# 12             Hotel QiK Stay at Crown Palace
# 13                      Kushabhau Thakre Hall
# 14                             royal building
# 15                               Vishram Grah
# 16                              Leela Heights
# 17                                 Lago Villa
# 18                   OYO 5201 Metro Home Stay
# 19                               Ellora Hotel
#
#                                                photos  \
# 0   [{'height': 768, 'html_attributions': ['<a hre...
# 1   [{'height': 3120, 'html_attributions': ['<a hr...
# 2   [{'height': 5344, 'html_attributions': ['<a hr...
# 3                                                 NaN
# 4   [{'height': 1483, 'html_attributions': ['<a hr...
# 5   [{'height': 427, 'html_attributions': ['<a hre...
# 6   [{'height': 716, 'html_attributions': ['<a hre...
# 7   [{'height': 1818, 'html_attributions': ['<a hr...
# 8   [{'height': 3456, 'html_attributions': ['<a hr...
# 9   [{'height': 3456, 'html_attributions': ['<a hr...
# 10  [{'height': 1536, 'html_attributions': ['<a hr...
# 11  [{'height': 428, 'html_attributions': ['<a hre...
# 12                                                NaN
# 13  [{'height': 4160, 'html_attributions': ['<a hr...
# 14                                                NaN
# 15  [{'height': 900, 'html_attributions': ['<a hre...
# 16  [{'height': 1080, 'html_attributions': ['<a hr...
# 17  [{'height': 1868, 'html_attributions': ['<a hr...
# 18  [{'height': 428, 'html_attributions': ['<a hre...
# 19  [{'height': 2340, 'html_attributions': ['<a hr...
#
#                        place_id  rating                    reference   scope  \
# 0   ChIJq1vvMa5CfDkRo3X_8kWkqyI     4.5  ChIJq1vvMa5CfDkRo3X_8kWkqyI  GOOGLE
# 1   ChIJi50ZiL1CfDkR4NRjELw2kqc     4.0  ChIJi50ZiL1CfDkR4NRjELw2kqc  GOOGLE
# 2   ChIJB-dTP5ZCfDkRoNVYLuMjz8A     3.6  ChIJB-dTP5ZCfDkRoNVYLuMjz8A  GOOGLE
# 3   ChIJ-44VhphCfDkReA5nJ_R2rp0     NaN  ChIJ-44VhphCfDkReA5nJ_R2rp0  GOOGLE
# 4   ChIJOUZz5r1CfDkRpgpb_baUKIQ     3.5  ChIJOUZz5r1CfDkRpgpb_baUKIQ  GOOGLE
# 5   ChIJzyD1DyddfDkRD0WckXbjY0c     3.3  ChIJzyD1DyddfDkRD0WckXbjY0c  GOOGLE
# 6   ChIJb1VVqZdCfDkRGMP9ppHLGYA     3.5  ChIJb1VVqZdCfDkRGMP9ppHLGYA  GOOGLE
# 7   ChIJOeOaOZZCfDkRnAWWAP5HG80     4.1  ChIJOeOaOZZCfDkRnAWWAP5HG80  GOOGLE
# 8   ChIJ_____7hCfDkRZmVtrnCCWqo     3.9  ChIJ_____7hCfDkRZmVtrnCCWqo  GOOGLE
# 9   ChIJib3B4pVCfDkRx5uggBhOTYY     4.0  ChIJib3B4pVCfDkRx5uggBhOTYY  GOOGLE
# 10  ChIJF6gtHpZCfDkRXhLGMRje3FY     3.8  ChIJF6gtHpZCfDkRXhLGMRje3FY  GOOGLE
# 11  ChIJBYQkRZZCfDkRrN89GT28aYs     1.0  ChIJBYQkRZZCfDkRrN89GT28aYs  GOOGLE
# 12  ChIJHaKq-r1CfDkR9vREzmgsqmI     5.0  ChIJHaKq-r1CfDkR9vREzmgsqmI  GOOGLE
# 13  ChIJweoMOZpCfDkRFK8Y-1wd52s     4.5  ChIJweoMOZpCfDkRFK8Y-1wd52s  GOOGLE
# 14  ChIJ9exdUrpCfDkR-gpAM7loek0     3.7  ChIJ9exdUrpCfDkR-gpAM7loek0  GOOGLE
# 15  ChIJ0ytE9qJCfDkRi8fX6nhR4p4     4.1  ChIJ0ytE9qJCfDkRi8fX6nhR4p4  GOOGLE
# 16  ChIJ4wZ4mKFCfDkRMYmHCtB7jQs     4.1  ChIJ4wZ4mKFCfDkRMYmHCtB7jQs  GOOGLE
# 17  ChIJfVnYIadCfDkRZL0MmErAf5A     4.3  ChIJfVnYIadCfDkRZL0MmErAf5A  GOOGLE
# 18  ChIJjSpCRq5CfDkREIClvMQLvHk     3.5  ChIJjSpCRq5CfDkREIClvMQLvHk  GOOGLE
# 19  ChIJq6qqapFCfDkR_U6OQ9tSsIk     3.4  ChIJq6qqapFCfDkR_U6OQ9tSsIk  GOOGLE
#
#     ... geometry.location.lat  geometry.location.lng  \
# 0   ...             23.240543              77.387223
# 1   ...             23.237078              77.401352
# 2   ...             23.236878              77.402730
# 3   ...             23.233374              77.411139
# 4   ...             23.237393              77.401493
# 5   ...             23.235214              77.399722
# 6   ...             23.233519              77.403267
# 7   ...             23.237129              77.402512
# 8   ...             23.234936              77.398980
# 9   ...             23.234855              77.402234
# 10  ...             23.236408              77.401440
# 11  ...             23.237162              77.403508
# 12  ...             23.235635              77.400628
# 13  ...             23.243466              77.406976
# 14  ...             23.236538              77.392524
# 15  ...             23.245567              77.398926
# 16  ...             23.248005              77.399037
# 17  ...             23.249148              77.394333
# 18  ...             23.241310              77.386160
# 19  ...             23.237007              77.408515
#
#    geometry.viewport.northeast.lat  geometry.viewport.northeast.lng  \
# 0                        23.241905                        77.388673
# 1                        23.238429                        77.402689
# 2                        23.238250                        77.404036
# 3                        23.234705                        77.412622
# 4                        23.238758                        77.402802
# 5                        23.236554                        77.401055
# 6                        23.234836                        77.404574
# 7                        23.238507                        77.403898
# 8                        23.236369                        77.400473
# 9                        23.236140                        77.403498
# 10                       23.237755                        77.402745
# 11                       23.238624                        77.404774
# 12                       23.236987                        77.401977
# 13                       23.244897                        77.408327
# 14                       23.237866                        77.393919
# 15                       23.247099                        77.400279
# 16                       23.249371                        77.400344
# 17                       23.250442                        77.395745
# 18                       23.242696                        77.387483
# 19                       23.238637                        77.409605
#
#     geometry.viewport.southwest.lat  geometry.viewport.southwest.lng  \
# 0                         23.239207                        77.385975
# 1                         23.235731                        77.399991
# 2                         23.235552                        77.401338
# 3                         23.232007                        77.409924
# 4                         23.236060                        77.400104
# 5                         23.233856                        77.398358
# 6                         23.232138                        77.401876
# 7                         23.235809                        77.401200
# 8                         23.233671                        77.397775
# 9                         23.233442                        77.400801
# 10                        23.235057                        77.400047
# 11                        23.235926                        77.402076
# 12                        23.234289                        77.399279
# 13                        23.242199                        77.405629
# 14                        23.235168                        77.391221
# 15                        23.244401                        77.397581
# 16                        23.246673                        77.397646
# 17                        23.247744                        77.393048
# 18                        23.239998                        77.384785
# 19                        23.235939                        77.406907
#
#                   plus_code.compound_code  plus_code.global_code  \
# 0   69RP+6V Bhopal, Madhya Pradesh, India            7JMV69RP+6V
# 1   6CP2+RG Bhopal, Madhya Pradesh, India            7JMV6CP2+RG
# 2   6CP3+Q3 Bhopal, Madhya Pradesh, India            7JMV6CP3+Q3
# 3   6CM6+8F Bhopal, Madhya Pradesh, India            7JMV6CM6+8F
# 4   6CP2+XH Bhopal, Madhya Pradesh, India            7JMV6CP2+XH
# 5   69PX+3V Bhopal, Madhya Pradesh, India            7JMV69PX+3V
# 6   6CM3+C8 Bhopal, Madhya Pradesh, India            7JMV6CM3+C8
# 7   6CP3+V2 Bhopal, Madhya Pradesh, India            7JMV6CP3+V2
# 8   69MX+XH Bhopal, Madhya Pradesh, India            7JMV69MX+XH
# 9   6CM2+WV Bhopal, Madhya Pradesh, India            7JMV6CM2+WV
# 10  6CP2+HH Bhopal, Madhya Pradesh, India            7JMV6CP2+HH
# 11  6CP3+VC Bhopal, Madhya Pradesh, India            7JMV6CP3+VC
# 12  6CP2+77 Bhopal, Madhya Pradesh, India            7JMV6CP2+77
# 13  6CV4+9Q Bhopal, Madhya Pradesh, India            7JMV6CV4+9Q
# 14  69PV+J2 Bhopal, Madhya Pradesh, India            7JMV69PV+J2
# 15  69WX+6H Bhopal, Madhya Pradesh, India            7JMV69WX+6H
# 16  69XX+6J Bhopal, Madhya Pradesh, India            7JMV69XX+6J
# 17  69XV+MP Bhopal, Madhya Pradesh, India            7JMV69XV+MP
# 18  69RP+GF Bhopal, Madhya Pradesh, India            7JMV69RP+GF
# 19                                    NaN                    NaN
#
#     opening_hours.open_now price_level
# 0                      NaN         NaN
# 1                      NaN         NaN
# 2                      NaN         NaN
# 3                      NaN         NaN
# 4                     True         NaN
# 5                     True         2.0
# 6                     True         NaN
# 7                     True         NaN
# 8                      NaN         NaN
# 9                      NaN         NaN
# 10                     NaN         NaN
# 11                    True         NaN
# 12                     NaN         NaN
# 13                   False         4.0
# 14                     NaN         NaN
# 15                     NaN         NaN
# 16                   False         NaN
# 17                     NaN         NaN
# 18                    True         NaN
# 19                     NaN         NaN
#
# [20 rows x 23 columns]

# %%
venues_food.columns
# Out:
# Index(['business_status', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'price_level',
#        'rating', 'reference', 'scope', 'types', 'user_ratings_total',
#        'vicinity', 'geometry.location.lat', 'geometry.location.lng',
#        'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng',
#        'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng',
#        'opening_hours.open_now', 'plus_code.compound_code',
#        'plus_code.global_code', 'permanently_closed'],
#       dtype='object')

# %%
venues_gym.columns
# Out:
# Index(['business_status', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'permanently_closed', 'place_id',
#        'rating', 'reference', 'scope', 'types', 'user_ratings_total',
#        'vicinity', 'geometry.location.lat', 'geometry.location.lng',
#        'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng',
#        'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng',
#        'plus_code.compound_code', 'plus_code.global_code', 'photos',
#        'opening_hours.open_now'],
#       dtype='object')

# %%
venues_lodg.columns
# Out:
# Index(['business_status', 'icon', 'icon_background_color',
#        'icon_mask_base_uri', 'name', 'photos', 'place_id', 'rating',
#        'reference', 'scope', 'types', 'user_ratings_total', 'vicinity',
#        'geometry.location.lat', 'geometry.location.lng',
#        'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng',
#        'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng',
#        'plus_code.compound_code', 'plus_code.global_code',
#        'opening_hours.open_now', 'price_level'],
#       dtype='object')

# %%
req_cols=['business_status', 'name', 'place_id',
       'rating', 'types', 'user_ratings_total',
       'vicinity', 'geometry.location.lat', 'geometry.location.lng', 'opening_hours.open_now']

req_cols2=[ 'geometry.location.lat', 'geometry.location.lng', 'name', 'types', 'vicinity']

# %%
Vf=venues_food[req_cols]
Vf
# Out:
#        business_status                                  name  \
# 0          OPERATIONAL     New Inn Restaurant & Coffee House
# 1   CLOSED_TEMPORARILY  Café Coffee Day - Usha Preet Complex
# 2          OPERATIONAL                         shasha's Cafe
# 3          OPERATIONAL        Guddu Tea Stall And Restaurant
# 4          OPERATIONAL                Azamgarh (Azmi Palace)
# 5          OPERATIONAL            Ambrosia Cafe & Restaurant
# 6          OPERATIONAL                 Prince Jaljira Center
# 7   CLOSED_TEMPORARILY                             Keventers
# 8          OPERATIONAL                         Tandoori Chai
# 9   CLOSED_TEMPORARILY                       Jyoti Tea Stall
# 10         OPERATIONAL                    Bhopali chai sutta
# 11         OPERATIONAL                Super tea coffee stall
# 12         OPERATIONAL                     Milkshake Kulture
# 13         OPERATIONAL                      DIET DESSERT CO.
# 14         OPERATIONAL                      Famous Soda Shop
# 15         OPERATIONAL       KULHADWAALA (DESI CHAI KA ADDA)
# 16         OPERATIONAL                   The Smokin'Shawarma
# 17         OPERATIONAL                         Ali Tea Stall
# 18         OPERATIONAL                          Bake-n-shake
# 19         OPERATIONAL                Teafriend's New Market
#
#                        place_id  rating  \
# 0   ChIJKQovNLlCfDkR2X4kQjn5ys8     3.7
# 1   ChIJyZqdspVCfDkR6YL3ElvMdcI     4.1
# 2   ChIJeUp3f8dCfDkRF8uLI1W-2NM     4.0
# 3   ChIJ-4c8b4RCfDkR9iJZc1K73pI     3.9
# 4   ChIJ5WA1f4NCfDkR5H7UZ_fh_XQ     4.0
# 5   ChIJMUoGB5ZCfDkR_jCAD3RXcKE     3.9
# 6   ChIJXf2Oz4hDfDkRWkk7htML9CM     3.7
# 7   ChIJ55q_Ab5CfDkRnyy3vXfan4c     4.3
# 8   ChIJ5WRghElDfDkRbjkUuTW8Vg0     5.0
# 9   ChIJmdbtM5ZCfDkRW0B2UYQPCvU     NaN
# 10  ChIJfZ6iHFFDfDkRS0Wxh4LZbro     NaN
# 11  ChIJY7esCC1DfDkR7WlZVpzlojs     5.0
# 12  ChIJkZCCTJRCfDkRXBqhzIBhXsg     4.1
# 13  ChIJAVQT4h9DfDkR4rKOgILG7M8     5.0
# 14  ChIJB8oFn71CfDkRUWinsqE75xI     5.0
# 15  ChIJjW4uoyRDfDkRrPIr28rMpc8     1.0
# 16  ChIJK_nH2PJDfDkRDsq2AJo4ej4     NaN
# 17  ChIJQ-U9Zb1CfDkRzk6QwKWqj8k     NaN
# 18  ChIJLYST1r1CfDkRlqlZd50lyWQ     4.3
# 19  ChIJE-Dgf75CfDkRHMn_GDEeEks     4.2
#
#                                                 types  user_ratings_total  \
# 0   [cafe, restaurant, food, point_of_interest, st...               837.0
# 1   [cafe, restaurant, food, point_of_interest, st...               158.0
# 2   [cafe, food, point_of_interest, store, establi...                11.0
# 3   [cafe, restaurant, food, point_of_interest, es...                72.0
# 4   [cafe, food, point_of_interest, store, establi...               342.0
# 5   [cafe, restaurant, food, point_of_interest, es...               144.0
# 6      [cafe, food, point_of_interest, establishment]                 3.0
# 7   [cafe, food, point_of_interest, store, establi...                82.0
# 8      [cafe, food, point_of_interest, establishment]                 6.0
# 9   [restaurant, cafe, food, point_of_interest, es...                 NaN
# 10  [cafe, food, point_of_interest, store, establi...                 NaN
# 11  [cafe, food, point_of_interest, store, establi...                 1.0
# 12  [cafe, food, point_of_interest, store, establi...               221.0
# 13     [cafe, food, point_of_interest, establishment]                 4.0
# 14     [cafe, food, point_of_interest, establishment]                 1.0
# 15     [cafe, food, point_of_interest, establishment]                 1.0
# 16     [cafe, food, point_of_interest, establishment]                 NaN
# 17  [restaurant, cafe, food, point_of_interest, es...                 NaN
# 18  [restaurant, cafe, food, point_of_interest, st...              2089.0
# 19  [cafe, food, point_of_interest, store, establi...                25.0
#
#                                              vicinity  geometry.location.lat  \
# 0    28, Bhadbhada Road, New Market, TT Nagar, Bhopal              23.236551
# 1   G 9 10, Usha Preet Complex, Maliviya Nagar, Ma...              23.234065
# 2               Bhadbhada Road, Shastri Nagar, Bhopal              23.228191
# 3   Jail Rd, 45, Jail Road, C.L.Colony, Jahangirab...              23.246871
# 4   Post Office Road, Pratap Nagar, Jahangirabad, ...              23.248258
# 5                35 New Market, Malviya Nagar, Bhopal              23.235122
# 6   Indian Cafe house back Side Main rode New auto...              23.234712
# 7   Shop No. 2, Plot No. 5, TT Nagar New Market, O...              23.234690
# 8        5, New Market, Samta Chowk, TT Nagar, Bhopal              23.235636
# 9          78, Roshanpura Road, Malviya Nagar, Bhopal              23.237675
# 10     Roshanpura, Roshanpura Slums, TT Nagar, Bhopal              23.238082
# 11  New Market Main Road, Near Hakeem Hotel, New M...              23.234591
# 12  No 129, Malviya Nagar, Near Emerge Store, Oppo...              23.233407
# 13                              Malviya Nagar, Bhopal              23.233419
# 14  G.T.B Complex, S-17, Bhadbhada Road, New Marke...              23.237028
# 15  behind HAWAII ADDA, S-50 GTB COMPLEX, behind H...              23.236797
# 16  near Chai Sutta bar, S-52 GTB complex, Rangmah...              23.236254
# 17       6CQ2+F79, Roshanpura Slums, TT Nagar, Bhopal              23.238659
# 18  Rangmahal Ciniplex Compund, 43, Bhadbhada Road...              23.234999
# 19  near Rangmahal talkies, Apoorti Super Bazaar c...              23.234651
#
#     geometry.location.lng opening_hours.open_now
# 0               77.400195                  False
# 1               77.402762                    NaN
# 2               77.392808                  False
# 3               77.416530                  False
# 4               77.415537                   True
# 5               77.401921                  False
# 6               77.401619                  False
# 7               77.401247                    NaN
# 8               77.400623                  False
# 9               77.402362                    NaN
# 10              77.401833                    NaN
# 11              77.400284                    NaN
# 12              77.404288                  False
# 13              77.404342                  False
# 14              77.399886                  False
# 15              77.399224                  False
# 16              77.399067                    NaN
# 17              77.400738                    NaN
# 18              77.398901                  False
# 19              77.398487                  False

# %%
Vg=venues_gym[req_cols]
Vg
# Out:
#        business_status                                               name  \
# 0   CLOSED_TEMPORARILY                            U.S. Fitness Club & Gym
# 1          OPERATIONAL                                     Vishal Fitness
# 2          OPERATIONAL                                  Amway Distributor
# 3          OPERATIONAL                         The Fitness World By C Max
# 4          OPERATIONAL                              The Fitness World Gym
# 5          OPERATIONAL                                       Essentia Spa
# 6          OPERATIONAL                                       Akhil Sports
# 7          OPERATIONAL  VLCC Wellness Center, (Malviya Nagar, New Mark...
# 8          OPERATIONAL                        STAY HEALTHY AND FIT CENTER
# 9          OPERATIONAL                            Gymnasium (Body Temple)
# 10         OPERATIONAL                                   Powermax Fitness
# 11         OPERATIONAL                         Control Room And Reception
# 12         OPERATIONAL                    he man gents parlour manoj umre
# 13         OPERATIONAL                          The Mark Fitness Care Gym
# 14         OPERATIONAL                                     Bhagvati Motor
# 15         OPERATIONAL             Nagar Palika Nigam Bhopal Vyayam Shala
# 16         OPERATIONAL                                         NITTTR Gym
# 17         OPERATIONAL             Bablu Fitnees Club And Slimming Centre
# 18         OPERATIONAL            Pioneer water sport and welfare society
# 19         OPERATIONAL                    म प्र प्रशासनिक सेवा संघ आकांशा
#
#                        place_id  rating  \
# 0   ChIJOcFFwupCfDkRqMU9QCvIVv4     3.4
# 1   ChIJp6pIpJJCfDkRnfDrCIjBGWE     4.3
# 2   ChIJa7aHlLhCfDkRWx2JtUC8E-o     3.7
# 3   ChIJUY0tUqRCfDkRnHRnJVdtkW0     5.0
# 4   ChIJM5aSR6FCfDkRfpwTr4OLu2k     3.8
# 5   ChIJWWacBq9CfDkRmRVpPEevKx8     NaN
# 6   ChIJEUtB3gJDfDkR7JttKHLPX4M     4.0
# 7   ChIJ____q5dCfDkRS6xIGKXtseg     4.5
# 8   ChIJn4YJT5RCfDkRI6il6T2wgqg     5.0
# 9   ChIJDZ_hMrxCfDkRzYOkWpee1pQ     4.2
# 10  ChIJa310p9VDfDkR7fFg8TwuB4Q     1.0
# 11  ChIJiRK3r79CfDkRjxZyzrHQDEk     3.0
# 12  ChIJb13Ftr5CfDkR0YBtKYrPeUw     NaN
# 13  ChIJs7jZErlCfDkRvzNfN6ljePs     4.3
# 14  ChIJSWwbbKJDfDkR3tWC779h6kU     NaN
# 15  ChIJmxPU1btCfDkRkjqt4MOMHHc     5.0
# 16  ChIJzWfJmaRCfDkRe1IcFvsM_74     4.0
# 17  ChIJtUD95bhCfDkRO-qQxZUspEg     4.0
# 18  ChIJS0gbFz5DfDkRfmsfh5ob34Q     NaN
# 19  ChIJ884BAO1CfDkR40qCSmuC_EI     4.0
#
#                                                 types  user_ratings_total  \
# 0     [gym, health, point_of_interest, establishment]                33.0
# 1     [gym, health, point_of_interest, establishment]               180.0
# 2     [gym, health, point_of_interest, establishment]                 3.0
# 3   [hospital, gym, health, point_of_interest, est...                 2.0
# 4     [gym, health, point_of_interest, establishment]                46.0
# 5     [gym, health, point_of_interest, establishment]                 NaN
# 6     [gym, health, point_of_interest, establishment]                 2.0
# 7   [beauty_salon, hair_care, doctor, gym, health,...               388.0
# 8     [gym, health, point_of_interest, establishment]                 2.0
# 9     [gym, health, point_of_interest, establishment]                33.0
# 10  [gym, health, point_of_interest, store, establ...                 1.0
# 11    [gym, health, point_of_interest, establishment]                 3.0
# 12    [gym, health, point_of_interest, establishment]                 NaN
# 13    [gym, health, point_of_interest, establishment]                17.0
# 14    [gym, health, point_of_interest, establishment]                 NaN
# 15    [gym, health, point_of_interest, establishment]                 1.0
# 16    [gym, health, point_of_interest, establishment]                23.0
# 17    [gym, health, point_of_interest, establishment]                22.0
# 18    [gym, health, point_of_interest, establishment]                 NaN
# 19    [gym, health, point_of_interest, establishment]                 2.0
#
#                                              vicinity  geometry.location.lat  \
# 0   Jain Mandir Road, Mata Mandir Opp.Platinum Pla...              23.227933
# 1   Link Road 1, 2nd Stop, STT Nagar, Shivaji Naga...              23.231111
# 2       Unnamed Road, Jawahar Chowk, TT Nagar, Bhopal              23.229793
# 3   27/B, Ali Ahina Building, Jehan Numa Rd, Rusta...              23.243630
# 4   Kamla Park Road, Yamuma Square, Polytechnic Sq...              23.247653
# 5                     69VP+5XQ, Shymala Hills, Bhopal              23.242963
# 6                        New Market Main Road, Bhopal              23.235542
# 7   above Virasat Showroom, 47/A,First floor Malvi...              23.238316
# 8            Link Road 1, Harshavardhan Nagar, Bhopal              23.233242
# 9   Opp. Rangmahal talkies, North TT Nagar, TT Nag...              23.235625
# 10       Advance Fitness, 6 AB, Malviya Nagar, Bhopal              23.239386
# 11              69JX+GM2, STT Nagar, TT Nagar, Bhopal              23.231269
# 12         69MW+9C4, North TT Nagar, TT Nagar, Bhopal              23.233391
# 13  69MV+3V9, MLA Quarters, North TT Nagar, TT Nag...              23.232663
# 14                                   69PV+PG8, Bhopal              23.236776
# 15  Ward No.27, Bhadbhada Road, Jawahar Chowk, Nor...              23.234457
# 16  462002, Rustam Ahaata Khan, Shymala Hills Slum...              23.241503
# 17  Top Floor, Galery Tower, Bhadbhada Road, Jawah...              23.230735
# 18              Minto Hall Road, Jahangirabad, Bhopal              23.245642
# 19                              Shivaji Nagar, Bhopal              23.226895
#
#     geometry.location.lng opening_hours.open_now
# 0               77.403255                    NaN
# 1               77.411518                  False
# 2               77.393845                    NaN
# 3               77.393051                  False
# 4               77.396430                  False
# 5               77.387470                    NaN
# 6               77.401278                  False
# 7               77.401282                  False
# 8               77.404814                   True
# 9               77.398364                  False
# 10              77.405268                    NaN
# 11              77.399128                    NaN
# 12              77.396088                  False
# 13              77.394737                  False
# 14              77.393839                  False
# 15              77.393071                  False
# 16              77.394738                  False
# 17              77.393801                  False
# 18              77.407174                    NaN
# 19              77.409953                    NaN

# %%
Vl=venues_lodg[req_cols]
Vl
# Out:
#    business_status                                       name  \
# 0      OPERATIONAL                    Jehan Numa Palace Hotel
# 1      OPERATIONAL                   OYO Rooms 094 New Market
# 2      OPERATIONAL  OYO Rooms Bhopal Malviya Nagar New Market
# 3      OPERATIONAL                 Hotel Shree Vinayak Palace
# 4      OPERATIONAL                               Hotel Pisals
# 5      OPERATIONAL                   OYO 24097 Hotel Gangotri
# 6      OPERATIONAL                                Saral Hotel
# 7      OPERATIONAL                         Shree Palace Hotel
# 8      OPERATIONAL                                 Park Hotel
# 9      OPERATIONAL                              Hotel Sarthak
# 10     OPERATIONAL                          Hotel Brij Palace
# 11     OPERATIONAL                 OYO 751 Hotel Shree Palace
# 12     OPERATIONAL             Hotel QiK Stay at Crown Palace
# 13     OPERATIONAL                      Kushabhau Thakre Hall
# 14     OPERATIONAL                             royal building
# 15     OPERATIONAL                               Vishram Grah
# 16     OPERATIONAL                              Leela Heights
# 17     OPERATIONAL                                 Lago Villa
# 18     OPERATIONAL                   OYO 5201 Metro Home Stay
# 19     OPERATIONAL                               Ellora Hotel
#
#                        place_id  rating  \
# 0   ChIJq1vvMa5CfDkRo3X_8kWkqyI     4.5
# 1   ChIJi50ZiL1CfDkR4NRjELw2kqc     4.0
# 2   ChIJB-dTP5ZCfDkRoNVYLuMjz8A     3.6
# 3   ChIJ-44VhphCfDkReA5nJ_R2rp0     NaN
# 4   ChIJOUZz5r1CfDkRpgpb_baUKIQ     3.5
# 5   ChIJzyD1DyddfDkRD0WckXbjY0c     3.3
# 6   ChIJb1VVqZdCfDkRGMP9ppHLGYA     3.5
# 7   ChIJOeOaOZZCfDkRnAWWAP5HG80     4.1
# 8   ChIJ_____7hCfDkRZmVtrnCCWqo     3.9
# 9   ChIJib3B4pVCfDkRx5uggBhOTYY     4.0
# 10  ChIJF6gtHpZCfDkRXhLGMRje3FY     3.8
# 11  ChIJBYQkRZZCfDkRrN89GT28aYs     1.0
# 12  ChIJHaKq-r1CfDkR9vREzmgsqmI     5.0
# 13  ChIJweoMOZpCfDkRFK8Y-1wd52s     4.5
# 14  ChIJ9exdUrpCfDkR-gpAM7loek0     3.7
# 15  ChIJ0ytE9qJCfDkRi8fX6nhR4p4     4.1
# 16  ChIJ4wZ4mKFCfDkRMYmHCtB7jQs     4.1
# 17  ChIJfVnYIadCfDkRZL0MmErAf5A     4.3
# 18  ChIJjSpCRq5CfDkREIClvMQLvHk     3.5
# 19  ChIJq6qqapFCfDkR_U6OQ9tSsIk     3.4
#
#                                                 types  user_ratings_total  \
# 0         [lodging, point_of_interest, establishment]              8102.0
# 1         [lodging, point_of_interest, establishment]                 1.0
# 2         [lodging, point_of_interest, establishment]                 7.0
# 3         [lodging, point_of_interest, establishment]                 NaN
# 4   [lodging, restaurant, food, point_of_interest,...               167.0
# 5         [lodging, point_of_interest, establishment]               181.0
# 6         [lodging, point_of_interest, establishment]               149.0
# 7         [lodging, point_of_interest, establishment]               557.0
# 8         [lodging, point_of_interest, establishment]               118.0
# 9         [lodging, point_of_interest, establishment]               980.0
# 10        [lodging, point_of_interest, establishment]               160.0
# 11        [lodging, point_of_interest, establishment]                 1.0
# 12        [lodging, point_of_interest, establishment]                 1.0
# 13  [lodging, restaurant, food, point_of_interest,...              1637.0
# 14        [lodging, point_of_interest, establishment]                 6.0
# 15        [lodging, point_of_interest, establishment]                17.0
# 16        [lodging, point_of_interest, establishment]                68.0
# 17        [lodging, point_of_interest, establishment]               142.0
# 18        [lodging, point_of_interest, establishment]                 2.0
# 19        [lodging, point_of_interest, establishment]                 7.0
#
#                                              vicinity  geometry.location.lat  \
# 0                     157, Shyamla Hills Road, Bhopal              23.240543
# 1     84, New Market Main Road, Malviya Nagar, Bhopal              23.237078
# 2   Malviya Shopping Center, 27-B, Roshanpura Road...              23.236878
# 3        R-37, M.P Nagar Zone 2 Near sankalp netralay              23.233374
# 4                29 New Market, Malviya Nagar, Bhopal              23.237393
# 5   near Sakshi Dhaba, 4 Bhadbhada Road New Kerva ...              23.235214
# 6                         47-B, Malviya Nagar, Bhopal              23.233519
# 7   Patrakar Bhavan, 135, Roshanpura Road, New Mar...              23.237129
# 8   Rang Mahal Tower Bhadbhada Rd, New Market, TT ...              23.234936
# 9   37 Opp. Indian Coffee House, New Market, Malvi...              23.234855
# 10  69, Malviya Nagar, New Market Main Road, New M...              23.236408
# 11  135, Patrakar Bhavan, Kamla Park Road, New Mar...              23.237162
# 12  2/36, Bhadbhada Road, New Market, STT Nagar, T...              23.235635
# 13                        opp. Governor House, Bhopal              23.243466
# 14  26/9, New Dushera Maidan, Banganga Slums, Nort...              23.236538
# 15  Kamla Park Road, Sardar Vallabh Bhai Patel Pol...              23.245567
# 16  10/3,Kamla Park Road, Civil Lines, Krishna Nag...              23.248005
# 17         17 Shamla Road, Bharat Bhawan Road, Bhopal              23.249148
# 18    Plot No.18, Nishat Manzil, Shimla Hills, Bhopal              23.241310
# 19  behind ETV Office, 98, Zone-2, Opposite SBI Co...              23.237007
#
#     geometry.location.lng opening_hours.open_now
# 0               77.387223                    NaN
# 1               77.401352                    NaN
# 2               77.402730                    NaN
# 3               77.411139                    NaN
# 4               77.401493                   True
# 5               77.399722                   True
# 6               77.403267                   True
# 7               77.402512                   True
# 8               77.398980                    NaN
# 9               77.402234                    NaN
# 10              77.401440                    NaN
# 11              77.403508                   True
# 12              77.400628                    NaN
# 13              77.406976                  False
# 14              77.392524                    NaN
# 15              77.398926                    NaN
# 16              77.399037                  False
# 17              77.394333                    NaN
# 18              77.386160                   True
# 19              77.408515                    NaN

# %%
f=['geometry.location.lat', 'geometry.location.lng']
X = Vf[f]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i 
     in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
f=['geometry.location.lat', 'geometry.location.lng']
X = Vg[f]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i 
     in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
f=['geometry.location.lat', 'geometry.location.lng']
X = Vl[f]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i 
     in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
Vf2=venues_food[req_cols2]
Vf2=Vf2.rename(columns={'geometry.location.lat': 'lat', 'geometry.location.lng': 'long'})
Vf2
# Out:
#           lat       long                                  name  \
# 0   23.236551  77.400195     New Inn Restaurant & Coffee House
# 1   23.234065  77.402762  Café Coffee Day - Usha Preet Complex
# 2   23.228191  77.392808                         shasha's Cafe
# 3   23.246871  77.416530        Guddu Tea Stall And Restaurant
# 4   23.248258  77.415537                Azamgarh (Azmi Palace)
# 5   23.235122  77.401921            Ambrosia Cafe & Restaurant
# 6   23.234712  77.401619                 Prince Jaljira Center
# 7   23.234690  77.401247                             Keventers
# 8   23.235636  77.400623                         Tandoori Chai
# 9   23.237675  77.402362                       Jyoti Tea Stall
# 10  23.238082  77.401833                    Bhopali chai sutta
# 11  23.234591  77.400284                Super tea coffee stall
# 12  23.233407  77.404288                     Milkshake Kulture
# 13  23.233419  77.404342                      DIET DESSERT CO.
# 14  23.237028  77.399886                      Famous Soda Shop
# 15  23.236797  77.399224       KULHADWAALA (DESI CHAI KA ADDA)
# 16  23.236254  77.399067                   The Smokin'Shawarma
# 17  23.238659  77.400738                         Ali Tea Stall
# 18  23.234999  77.398901                          Bake-n-shake
# 19  23.234651  77.398487                Teafriend's New Market
#
#                                                 types  \
# 0   [cafe, restaurant, food, point_of_interest, st...
# 1   [cafe, restaurant, food, point_of_interest, st...
# 2   [cafe, food, point_of_interest, store, establi...
# 3   [cafe, restaurant, food, point_of_interest, es...
# 4   [cafe, food, point_of_interest, store, establi...
# 5   [cafe, restaurant, food, point_of_interest, es...
# 6      [cafe, food, point_of_interest, establishment]
# 7   [cafe, food, point_of_interest, store, establi...
# 8      [cafe, food, point_of_interest, establishment]
# 9   [restaurant, cafe, food, point_of_interest, es...
# 10  [cafe, food, point_of_interest, store, establi...
# 11  [cafe, food, point_of_interest, store, establi...
# 12  [cafe, food, point_of_interest, store, establi...
# 13     [cafe, food, point_of_interest, establishment]
# 14     [cafe, food, point_of_interest, establishment]
# 15     [cafe, food, point_of_interest, establishment]
# 16     [cafe, food, point_of_interest, establishment]
# 17  [restaurant, cafe, food, point_of_interest, es...
# 18  [restaurant, cafe, food, point_of_interest, st...
# 19  [cafe, food, point_of_interest, store, establi...
#
#                                              vicinity
# 0    28, Bhadbhada Road, New Market, TT Nagar, Bhopal
# 1   G 9 10, Usha Preet Complex, Maliviya Nagar, Ma...
# 2               Bhadbhada Road, Shastri Nagar, Bhopal
# 3   Jail Rd, 45, Jail Road, C.L.Colony, Jahangirab...
# 4   Post Office Road, Pratap Nagar, Jahangirabad, ...
# 5                35 New Market, Malviya Nagar, Bhopal
# 6   Indian Cafe house back Side Main rode New auto...
# 7   Shop No. 2, Plot No. 5, TT Nagar New Market, O...
# 8        5, New Market, Samta Chowk, TT Nagar, Bhopal
# 9          78, Roshanpura Road, Malviya Nagar, Bhopal
# 10     Roshanpura, Roshanpura Slums, TT Nagar, Bhopal
# 11  New Market Main Road, Near Hakeem Hotel, New M...
# 12  No 129, Malviya Nagar, Near Emerge Store, Oppo...
# 13                              Malviya Nagar, Bhopal
# 14  G.T.B Complex, S-17, Bhadbhada Road, New Marke...
# 15  behind HAWAII ADDA, S-50 GTB COMPLEX, behind H...
# 16  near Chai Sutta bar, S-52 GTB complex, Rangmah...
# 17       6CQ2+F79, Roshanpura Slums, TT Nagar, Bhopal
# 18  Rangmahal Ciniplex Compund, 43, Bhadbhada Road...
# 19  near Rangmahal talkies, Apoorti Super Bazaar c...

# %%
Vg2=venues_gym[req_cols2]
Vg2=Vg2.rename(columns={'geometry.location.lat': 'lat', 'geometry.location.lng': 'long'})
Vg2
# Out:
#           lat       long                                               name  \
# 0   23.227933  77.403255                            U.S. Fitness Club & Gym
# 1   23.231111  77.411518                                     Vishal Fitness
# 2   23.229793  77.393845                                  Amway Distributor
# 3   23.243630  77.393051                         The Fitness World By C Max
# 4   23.247653  77.396430                              The Fitness World Gym
# 5   23.242963  77.387470                                       Essentia Spa
# 6   23.235542  77.401278                                       Akhil Sports
# 7   23.238316  77.401282  VLCC Wellness Center, (Malviya Nagar, New Mark...
# 8   23.233242  77.404814                        STAY HEALTHY AND FIT CENTER
# 9   23.235625  77.398364                            Gymnasium (Body Temple)
# 10  23.239386  77.405268                                   Powermax Fitness
# 11  23.231269  77.399128                         Control Room And Reception
# 12  23.233391  77.396088                    he man gents parlour manoj umre
# 13  23.232663  77.394737                          The Mark Fitness Care Gym
# 14  23.236776  77.393839                                     Bhagvati Motor
# 15  23.234457  77.393071             Nagar Palika Nigam Bhopal Vyayam Shala
# 16  23.241503  77.394738                                         NITTTR Gym
# 17  23.230735  77.393801             Bablu Fitnees Club And Slimming Centre
# 18  23.245642  77.407174            Pioneer water sport and welfare society
# 19  23.226895  77.409953                    म प्र प्रशासनिक सेवा संघ आकांशा
#
#                                                 types  \
# 0     [gym, health, point_of_interest, establishment]
# 1     [gym, health, point_of_interest, establishment]
# 2     [gym, health, point_of_interest, establishment]
# 3   [hospital, gym, health, point_of_interest, est...
# 4     [gym, health, point_of_interest, establishment]
# 5     [gym, health, point_of_interest, establishment]
# 6     [gym, health, point_of_interest, establishment]
# 7   [beauty_salon, hair_care, doctor, gym, health,...
# 8     [gym, health, point_of_interest, establishment]
# 9     [gym, health, point_of_interest, establishment]
# 10  [gym, health, point_of_interest, store, establ...
# 11    [gym, health, point_of_interest, establishment]
# 12    [gym, health, point_of_interest, establishment]
# 13    [gym, health, point_of_interest, establishment]
# 14    [gym, health, point_of_interest, establishment]
# 15    [gym, health, point_of_interest, establishment]
# 16    [gym, health, point_of_interest, establishment]
# 17    [gym, health, point_of_interest, establishment]
# 18    [gym, health, point_of_interest, establishment]
# 19    [gym, health, point_of_interest, establishment]
#
#                                              vicinity
# 0   Jain Mandir Road, Mata Mandir Opp.Platinum Pla...
# 1   Link Road 1, 2nd Stop, STT Nagar, Shivaji Naga...
# 2       Unnamed Road, Jawahar Chowk, TT Nagar, Bhopal
# 3   27/B, Ali Ahina Building, Jehan Numa Rd, Rusta...
# 4   Kamla Park Road, Yamuma Square, Polytechnic Sq...
# 5                     69VP+5XQ, Shymala Hills, Bhopal
# 6                        New Market Main Road, Bhopal
# 7   above Virasat Showroom, 47/A,First floor Malvi...
# 8            Link Road 1, Harshavardhan Nagar, Bhopal
# 9   Opp. Rangmahal talkies, North TT Nagar, TT Nag...
# 10       Advance Fitness, 6 AB, Malviya Nagar, Bhopal
# 11              69JX+GM2, STT Nagar, TT Nagar, Bhopal
# 12         69MW+9C4, North TT Nagar, TT Nagar, Bhopal
# 13  69MV+3V9, MLA Quarters, North TT Nagar, TT Nag...
# 14                                   69PV+PG8, Bhopal
# 15  Ward No.27, Bhadbhada Road, Jawahar Chowk, Nor...
# 16  462002, Rustam Ahaata Khan, Shymala Hills Slum...
# 17  Top Floor, Galery Tower, Bhadbhada Road, Jawah...
# 18              Minto Hall Road, Jahangirabad, Bhopal
# 19                              Shivaji Nagar, Bhopal

# %%
Vl2=venues_lodg[req_cols2]
Vl2=Vl2.rename(columns={'geometry.location.lat': 'lat', 'geometry.location.lng': 'long'})
Vl2
# Out:
#           lat       long                                       name  \
# 0   23.240543  77.387223                    Jehan Numa Palace Hotel
# 1   23.237078  77.401352                   OYO Rooms 094 New Market
# 2   23.236878  77.402730  OYO Rooms Bhopal Malviya Nagar New Market
# 3   23.233374  77.411139                 Hotel Shree Vinayak Palace
# 4   23.237393  77.401493                               Hotel Pisals
# 5   23.235214  77.399722                   OYO 24097 Hotel Gangotri
# 6   23.233519  77.403267                                Saral Hotel
# 7   23.237129  77.402512                         Shree Palace Hotel
# 8   23.234936  77.398980                                 Park Hotel
# 9   23.234855  77.402234                              Hotel Sarthak
# 10  23.236408  77.401440                          Hotel Brij Palace
# 11  23.237162  77.403508                 OYO 751 Hotel Shree Palace
# 12  23.235635  77.400628             Hotel QiK Stay at Crown Palace
# 13  23.243466  77.406976                      Kushabhau Thakre Hall
# 14  23.236538  77.392524                             royal building
# 15  23.245567  77.398926                               Vishram Grah
# 16  23.248005  77.399037                              Leela Heights
# 17  23.249148  77.394333                                 Lago Villa
# 18  23.241310  77.386160                   OYO 5201 Metro Home Stay
# 19  23.237007  77.408515                               Ellora Hotel
#
#                                                 types  \
# 0         [lodging, point_of_interest, establishment]
# 1         [lodging, point_of_interest, establishment]
# 2         [lodging, point_of_interest, establishment]
# 3         [lodging, point_of_interest, establishment]
# 4   [lodging, restaurant, food, point_of_interest,...
# 5         [lodging, point_of_interest, establishment]
# 6         [lodging, point_of_interest, establishment]
# 7         [lodging, point_of_interest, establishment]
# 8         [lodging, point_of_interest, establishment]
# 9         [lodging, point_of_interest, establishment]
# 10        [lodging, point_of_interest, establishment]
# 11        [lodging, point_of_interest, establishment]
# 12        [lodging, point_of_interest, establishment]
# 13  [lodging, restaurant, food, point_of_interest,...
# 14        [lodging, point_of_interest, establishment]
# 15        [lodging, point_of_interest, establishment]
# 16        [lodging, point_of_interest, establishment]
# 17        [lodging, point_of_interest, establishment]
# 18        [lodging, point_of_interest, establishment]
# 19        [lodging, point_of_interest, establishment]
#
#                                              vicinity
# 0                     157, Shyamla Hills Road, Bhopal
# 1     84, New Market Main Road, Malviya Nagar, Bhopal
# 2   Malviya Shopping Center, 27-B, Roshanpura Road...
# 3        R-37, M.P Nagar Zone 2 Near sankalp netralay
# 4                29 New Market, Malviya Nagar, Bhopal
# 5   near Sakshi Dhaba, 4 Bhadbhada Road New Kerva ...
# 6                         47-B, Malviya Nagar, Bhopal
# 7   Patrakar Bhavan, 135, Roshanpura Road, New Mar...
# 8   Rang Mahal Tower Bhadbhada Rd, New Market, TT ...
# 9   37 Opp. Indian Coffee House, New Market, Malvi...
# 10  69, Malviya Nagar, New Market Main Road, New M...
# 11  135, Patrakar Bhavan, Kamla Park Road, New Mar...
# 12  2/36, Bhadbhada Road, New Market, STT Nagar, T...
# 13                        opp. Governor House, Bhopal
# 14  26/9, New Dushera Maidan, Banganga Slums, Nort...
# 15  Kamla Park Road, Sardar Vallabh Bhai Patel Pol...
# 16  10/3,Kamla Park Road, Civil Lines, Krishna Nag...
# 17         17 Shamla Road, Bharat Bhawan Road, Bhopal
# 18    Plot No.18, Nishat Manzil, Shimla Hills, Bhopal
# 19  behind ETV Office, 98, Zone-2, Opposite SBI Co...

# %%
map = folium.Map(location=[23.259933, 77.412615], zoom_start=13)
for i, row in Vf2.iterrows():
    folium.CircleMarker(location=[row['lat'], row['long']], popup=row["name"]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_573e83fd40984c7a8c61022e3cef1e17%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_573e83fd40984c7a8c61022e3cef1e17%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_573e83fd40984c7a8c61022e3cef1e17%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_573e83fd40984c7a8c61022e3cef1e17%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B23.259933%2C%2077.412615%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
map = folium.Map(location=[23.259933, 77.412615], zoom_start=13)
for i, row in Vg2.iterrows():
    folium.CircleMarker(location=[row['lat'], row['long']], color='red', popup=row["name"]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a38cf0a521a94b8c982746cf13ebd262%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a38cf0a521a94b8c982746cf13ebd262%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a38cf0a521a94b8c982746cf13ebd262%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a38cf0a521a94b8c982746cf13ebd262%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B23.259933%2C%2077.412615%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
map = folium.Map(location=[23.259933, 77.412615], zoom_start=13)
for i, row in Vl2.iterrows():
    folium.CircleMarker(location=[row['lat'], row['long']], color='green', popup=row["name"]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ba9e1d7fda7e45f695c2527ed9b2f4ea%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ba9e1d7fda7e45f695c2527ed9b2f4ea%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ba9e1d7fda7e45f695c2527ed9b2f4ea%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ba9e1d7fda7e45f695c2527ed9b2f4ea%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B23.259933%2C%2077.412615%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Food Venues

# %%
X = Vf2[["lat","long"]]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
k = 7
model = cluster.KMeans(n_clusters=k, init='k-means++')
X = Vf2[["lat","long"]]
## clustering
dtf_X = X.copy()
dtf_X["cluster"] = model.fit_predict(X)
## find real centroids
closest, distances = scipy.cluster.vq.vq(model.cluster_centers_, 
                     dtf_X.drop("cluster", axis=1).values)
dtf_X["centroids"] = 0
for i in closest:
    dtf_X["centroids"].iloc[i] = 1
## add clustering info to the original dataset
Vf2[["cluster","centroids"]] = dtf_X[["cluster","centroids"]]
Vf2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#           lat       long                                  name  \
# 0   23.236551  77.400195     New Inn Restaurant & Coffee House
# 1   23.234065  77.402762  Café Coffee Day - Usha Preet Complex
# 2   23.228191  77.392808                         shasha's Cafe
# 3   23.246871  77.416530        Guddu Tea Stall And Restaurant
# 4   23.248258  77.415537                Azamgarh (Azmi Palace)
# 5   23.235122  77.401921            Ambrosia Cafe & Restaurant
# 6   23.234712  77.401619                 Prince Jaljira Center
# 7   23.234690  77.401247                             Keventers
# 8   23.235636  77.400623                         Tandoori Chai
# 9   23.237675  77.402362                       Jyoti Tea Stall
# 10  23.238082  77.401833                    Bhopali chai sutta
# 11  23.234591  77.400284                Super tea coffee stall
# 12  23.233407  77.404288                     Milkshake Kulture
# 13  23.233419  77.404342                      DIET DESSERT CO.
# 14  23.237028  77.399886                      Famous Soda Shop
# 15  23.236797  77.399224       KULHADWAALA (DESI CHAI KA ADDA)
# 16  23.236254  77.399067                   The Smokin'Shawarma
# 17  23.238659  77.400738                         Ali Tea Stall
# 18  23.234999  77.398901                          Bake-n-shake
# 19  23.234651  77.398487                Teafriend's New Market
#
#                                                 types  \
# 0   [cafe, restaurant, food, point_of_interest, st...
# 1   [cafe, restaurant, food, point_of_interest, st...
# 2   [cafe, food, point_of_interest, store, establi...
# 3   [cafe, restaurant, food, point_of_interest, es...
# 4   [cafe, food, point_of_interest, store, establi...
# 5   [cafe, restaurant, food, point_of_interest, es...
# 6      [cafe, food, point_of_interest, establishment]
# 7   [cafe, food, point_of_interest, store, establi...
# 8      [cafe, food, point_of_interest, establishment]
# 9   [restaurant, cafe, food, point_of_interest, es...
# 10  [cafe, food, point_of_interest, store, establi...
# 11  [cafe, food, point_of_interest, store, establi...
# 12  [cafe, food, point_of_interest, store, establi...
# 13     [cafe, food, point_of_interest, establishment]
# 14     [cafe, food, point_of_interest, establishment]
# 15     [cafe, food, point_of_interest, establishment]
# 16     [cafe, food, point_of_interest, establishment]
# 17  [restaurant, cafe, food, point_of_interest, es...
# 18  [restaurant, cafe, food, point_of_interest, st...
# 19  [cafe, food, point_of_interest, store, establi...
#
#                                              vicinity  cluster  centroids
# 0    28, Bhadbhada Road, New Market, TT Nagar, Bhopal        6          0
# 1   G 9 10, Usha Preet Complex, Maliviya Nagar, Ma...        4          0
# 2               Bhadbhada Road, Shastri Nagar, Bhopal        3          1
# 3   Jail Rd, 45, Jail Road, C.L.Colony, Jahangirab...        1          1
# 4   Post Office Road, Pratap Nagar, Jahangirabad, ...        1          0
# 5                35 New Market, Malviya Nagar, Bhopal        5          0
# 6   Indian Cafe house back Side Main rode New auto...        5          0
# 7   Shop No. 2, Plot No. 5, TT Nagar New Market, O...        5          1
# 8        5, New Market, Samta Chowk, TT Nagar, Bhopal        5          0
# 9          78, Roshanpura Road, Malviya Nagar, Bhopal        0          0
# 10     Roshanpura, Roshanpura Slums, TT Nagar, Bhopal        0          1
# 11  New Market Main Road, Near Hakeem Hotel, New M...        5          0
# 12  No 129, Malviya Nagar, Near Emerge Store, Oppo...        4          1
# 13                              Malviya Nagar, Bhopal        4          0
# 14  G.T.B Complex, S-17, Bhadbhada Road, New Marke...        6          0
# 15  behind HAWAII ADDA, S-50 GTB COMPLEX, behind H...        6          1
# 16  near Chai Sutta bar, S-52 GTB complex, Rangmah...        6          0
# 17       6CQ2+F79, Roshanpura Slums, TT Nagar, Bhopal        0          0
# 18  Rangmahal Ciniplex Compund, 43, Bhadbhada Road...        2          0
# 19  near Rangmahal talkies, Apoorti Super Bazaar c...        2          1

# %%
fig, ax = plt.subplots()
sns.scatterplot(x="lat", y="long", data=Vf2, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief", ax=ax).set_title('Clustering (k='+str(k)+')')
th_centroids = model.cluster_centers_
ax.scatter(th_centroids[:,0], th_centroids[:,1], s=50, c='black', 
           marker="x")

# %%
model = cluster.AffinityPropagation()

# %%
k = Vf2["cluster"].nunique()
sns.scatterplot(x="lat", y="long", data=Vf2, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief").set_title('Clustering (k='+str(k)+')')
# Out:
# Text(0.5, 1.0, 'Clustering (k=7)')

# %% [markdown]
# ### Gym Venues

# %%
X = Vg2[["lat","long"]]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
k = 6
model = cluster.KMeans(n_clusters=k, init='k-means++')
X = Vg2[["lat","long"]]
## clustering
dtf_X = X.copy()
dtf_X["cluster"] = model.fit_predict(X)
## find real centroids
closest, distances = scipy.cluster.vq.vq(model.cluster_centers_, 
                     dtf_X.drop("cluster", axis=1).values)
dtf_X["centroids"] = 0
for i in closest:
    dtf_X["centroids"].iloc[i] = 1
## add clustering info to the original dataset
Vg2[["cluster","centroids"]] = dtf_X[["cluster","centroids"]]
Vg2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#           lat       long                                               name  \
# 0   23.227933  77.403255                            U.S. Fitness Club & Gym
# 1   23.231111  77.411518                                     Vishal Fitness
# 2   23.229793  77.393845                                  Amway Distributor
# 3   23.243630  77.393051                         The Fitness World By C Max
# 4   23.247653  77.396430                              The Fitness World Gym
# 5   23.242963  77.387470                                       Essentia Spa
# 6   23.235542  77.401278                                       Akhil Sports
# 7   23.238316  77.401282  VLCC Wellness Center, (Malviya Nagar, New Mark...
# 8   23.233242  77.404814                        STAY HEALTHY AND FIT CENTER
# 9   23.235625  77.398364                            Gymnasium (Body Temple)
# 10  23.239386  77.405268                                   Powermax Fitness
# 11  23.231269  77.399128                         Control Room And Reception
# 12  23.233391  77.396088                    he man gents parlour manoj umre
# 13  23.232663  77.394737                          The Mark Fitness Care Gym
# 14  23.236776  77.393839                                     Bhagvati Motor
# 15  23.234457  77.393071             Nagar Palika Nigam Bhopal Vyayam Shala
# 16  23.241503  77.394738                                         NITTTR Gym
# 17  23.230735  77.393801             Bablu Fitnees Club And Slimming Centre
# 18  23.245642  77.407174            Pioneer water sport and welfare society
# 19  23.226895  77.409953                    म प्र प्रशासनिक सेवा संघ आकांशा
#
#                                                 types  \
# 0     [gym, health, point_of_interest, establishment]
# 1     [gym, health, point_of_interest, establishment]
# 2     [gym, health, point_of_interest, establishment]
# 3   [hospital, gym, health, point_of_interest, est...
# 4     [gym, health, point_of_interest, establishment]
# 5     [gym, health, point_of_interest, establishment]
# 6     [gym, health, point_of_interest, establishment]
# 7   [beauty_salon, hair_care, doctor, gym, health,...
# 8     [gym, health, point_of_interest, establishment]
# 9     [gym, health, point_of_interest, establishment]
# 10  [gym, health, point_of_interest, store, establ...
# 11    [gym, health, point_of_interest, establishment]
# 12    [gym, health, point_of_interest, establishment]
# 13    [gym, health, point_of_interest, establishment]
# 14    [gym, health, point_of_interest, establishment]
# 15    [gym, health, point_of_interest, establishment]
# 16    [gym, health, point_of_interest, establishment]
# 17    [gym, health, point_of_interest, establishment]
# 18    [gym, health, point_of_interest, establishment]
# 19    [gym, health, point_of_interest, establishment]
#
#                                              vicinity  cluster  centroids
# 0   Jain Mandir Road, Mata Mandir Opp.Platinum Pla...        4          1
# 1   Link Road 1, 2nd Stop, STT Nagar, Shivaji Naga...        1          0
# 2       Unnamed Road, Jawahar Chowk, TT Nagar, Bhopal        2          0
# 3   27/B, Ali Ahina Building, Jehan Numa Rd, Rusta...        3          1
# 4   Kamla Park Road, Yamuma Square, Polytechnic Sq...        3          0
# 5                     69VP+5XQ, Shymala Hills, Bhopal        3          0
# 6                        New Market Main Road, Bhopal        0          1
# 7   above Virasat Showroom, 47/A,First floor Malvi...        0          0
# 8            Link Road 1, Harshavardhan Nagar, Bhopal        0          0
# 9   Opp. Rangmahal talkies, North TT Nagar, TT Nag...        0          0
# 10       Advance Fitness, 6 AB, Malviya Nagar, Bhopal        5          1
# 11              69JX+GM2, STT Nagar, TT Nagar, Bhopal        4          0
# 12         69MW+9C4, North TT Nagar, TT Nagar, Bhopal        2          0
# 13  69MV+3V9, MLA Quarters, North TT Nagar, TT Nag...        2          1
# 14                                   69PV+PG8, Bhopal        2          0
# 15  Ward No.27, Bhadbhada Road, Jawahar Chowk, Nor...        2          0
# 16  462002, Rustam Ahaata Khan, Shymala Hills Slum...        3          0
# 17  Top Floor, Galery Tower, Bhadbhada Road, Jawah...        2          0
# 18              Minto Hall Road, Jahangirabad, Bhopal        5          0
# 19                              Shivaji Nagar, Bhopal        1          1

# %%
fig, ax = plt.subplots()
sns.scatterplot(x="lat", y="long", data=Vg2, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief", ax=ax).set_title('Clustering (k='+str(k)+')')
th_centroids = model.cluster_centers_
ax.scatter(th_centroids[:,0], th_centroids[:,1], s=50, c='black', 
           marker="x")

# %%
model = cluster.AffinityPropagation()

# %%
k = Vg2["cluster"].nunique()
sns.scatterplot(x="lat", y="long", data=Vg2, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief").set_title('Clustering (k='+str(k)+')')
# Out:
# Text(0.5, 1.0, 'Clustering (k=6)')

# %% [markdown]
# ### Lodging Venues

# %%
X = Vl2[["lat","long"]]
max_k = 10
## iterations
distortions = [] 
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters', 
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
k = 5
model = cluster.KMeans(n_clusters=k, init='k-means++')
X = Vl2[["lat","long"]]
## clustering
dtf_X = X.copy()
dtf_X["cluster"] = model.fit_predict(X)
## find real centroids
closest, distances = scipy.cluster.vq.vq(model.cluster_centers_, 
                     dtf_X.drop("cluster", axis=1).values)
dtf_X["centroids"] = 0
for i in closest:
    dtf_X["centroids"].iloc[i] = 1
## add clustering info to the original dataset
Vl2[["cluster","centroids"]] = dtf_X[["cluster","centroids"]]
Vl2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#           lat       long                                       name  \
# 0   23.240543  77.387223                    Jehan Numa Palace Hotel
# 1   23.237078  77.401352                   OYO Rooms 094 New Market
# 2   23.236878  77.402730  OYO Rooms Bhopal Malviya Nagar New Market
# 3   23.233374  77.411139                 Hotel Shree Vinayak Palace
# 4   23.237393  77.401493                               Hotel Pisals
# 5   23.235214  77.399722                   OYO 24097 Hotel Gangotri
# 6   23.233519  77.403267                                Saral Hotel
# 7   23.237129  77.402512                         Shree Palace Hotel
# 8   23.234936  77.398980                                 Park Hotel
# 9   23.234855  77.402234                              Hotel Sarthak
# 10  23.236408  77.401440                          Hotel Brij Palace
# 11  23.237162  77.403508                 OYO 751 Hotel Shree Palace
# 12  23.235635  77.400628             Hotel QiK Stay at Crown Palace
# 13  23.243466  77.406976                      Kushabhau Thakre Hall
# 14  23.236538  77.392524                             royal building
# 15  23.245567  77.398926                               Vishram Grah
# 16  23.248005  77.399037                              Leela Heights
# 17  23.249148  77.394333                                 Lago Villa
# 18  23.241310  77.386160                   OYO 5201 Metro Home Stay
# 19  23.237007  77.408515                               Ellora Hotel
#
#                                                 types  \
# 0         [lodging, point_of_interest, establishment]
# 1         [lodging, point_of_interest, establishment]
# 2         [lodging, point_of_interest, establishment]
# 3         [lodging, point_of_interest, establishment]
# 4   [lodging, restaurant, food, point_of_interest,...
# 5         [lodging, point_of_interest, establishment]
# 6         [lodging, point_of_interest, establishment]
# 7         [lodging, point_of_interest, establishment]
# 8         [lodging, point_of_interest, establishment]
# 9         [lodging, point_of_interest, establishment]
# 10        [lodging, point_of_interest, establishment]
# 11        [lodging, point_of_interest, establishment]
# 12        [lodging, point_of_interest, establishment]
# 13  [lodging, restaurant, food, point_of_interest,...
# 14        [lodging, point_of_interest, establishment]
# 15        [lodging, point_of_interest, establishment]
# 16        [lodging, point_of_interest, establishment]
# 17        [lodging, point_of_interest, establishment]
# 18        [lodging, point_of_interest, establishment]
# 19        [lodging, point_of_interest, establishment]
#
#                                              vicinity  cluster  centroids
# 0                     157, Shyamla Hills Road, Bhopal        2          1
# 1     84, New Market Main Road, Malviya Nagar, Bhopal        1          0
# 2   Malviya Shopping Center, 27-B, Roshanpura Road...        1          0
# 3        R-37, M.P Nagar Zone 2 Near sankalp netralay        3          1
# 4                29 New Market, Malviya Nagar, Bhopal        1          0
# 5   near Sakshi Dhaba, 4 Bhadbhada Road New Kerva ...        1          0
# 6                         47-B, Malviya Nagar, Bhopal        1          0
# 7   Patrakar Bhavan, 135, Roshanpura Road, New Mar...        1          0
# 8   Rang Mahal Tower Bhadbhada Rd, New Market, TT ...        1          0
# 9   37 Opp. Indian Coffee House, New Market, Malvi...        1          0
# 10  69, Malviya Nagar, New Market Main Road, New M...        1          1
# 11  135, Patrakar Bhavan, Kamla Park Road, New Mar...        1          0
# 12  2/36, Bhadbhada Road, New Market, STT Nagar, T...        1          0
# 13                        opp. Governor House, Bhopal        4          1
# 14  26/9, New Dushera Maidan, Banganga Slums, Nort...        2          0
# 15  Kamla Park Road, Sardar Vallabh Bhai Patel Pol...        0          0
# 16  10/3,Kamla Park Road, Civil Lines, Krishna Nag...        0          1
# 17         17 Shamla Road, Bharat Bhawan Road, Bhopal        0          0
# 18    Plot No.18, Nishat Manzil, Shimla Hills, Bhopal        2          0
# 19  behind ETV Office, 98, Zone-2, Opposite SBI Co...        3          0

# %%
fig, ax = plt.subplots()
sns.scatterplot(x="lat", y="long", data=Vl2, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief", ax=ax).set_title('Clustering (k='+str(k)+')')
th_centroids = model.cluster_centers_
ax.scatter(th_centroids[:,0], th_centroids[:,1], s=50, c='black', 
           marker="x")

# %%
model = cluster.AffinityPropagation()

# %%
k = Vl2["cluster"].nunique()
sns.scatterplot(x="lat", y="long", data=Vl2, 
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief").set_title('Clustering (k='+str(k)+')')
# Out:
# Text(0.5, 1.0, 'Clustering (k=5)')

# %% [markdown]
# # PLOTTING ON MAP

# %% [markdown]
# ## For Food Venues

# %%
x, y = "lat", "long"
color = "cluster"
popup = "name"
marker = "centroids"
location = [23.236551, 77.400195]
data = Vf2.copy()
## create color column
lst_elements = sorted(list(Vf2[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in 
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])

## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=13)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], 
           color=row["color"], fill=True,popup=row[popup]).add_to(map_), axis=1)

## add centroids marker
lst_elements = sorted(list(Vf2[marker].unique()))
data[data[marker]==1].apply(lambda row: 
           folium.Marker(location=[row[x],row[y]], 
           draggable=False,  popup=row[popup] ,       
           icon=folium.DivIcon(html=f"""
            <div><svg>
                <circle cx="25" cy="25" r="20" fill="#69b3a2" opacity=".4"/>
                <rect x="20", y="20" width="10" height="10", fill="white", opacity=".5" 
            </svg></div>""")
    ).add_to(map_), axis=1)
## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ba395765d2744f19bd6fed282bde462f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ba395765d2744f19bd6fed282bde462f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ba395765d2744f19bd6fed282bde462f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ba395765d2744f19bd6fed282bde462f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B23.236551%2C%2077.400195%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## For Gym Venues

# %%
x, y = "lat", "long"
color = "cluster"
popup = "name"
marker = "centroids"
location = [23.227933, 77.403255]
data = Vg2.copy()
## create color column
lst_elements = sorted(list(Vg2[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in 
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])

## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=13)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], 
           color=row["color"], fill=True,popup=row[popup]).add_to(map_), axis=1)

## add centroids marker
lst_elements = sorted(list(Vg2[marker].unique()))
data[data[marker]==1].apply(lambda row: 
           folium.Marker(location=[row[x],row[y]], 
           draggable=False,  popup=row[popup] ,       
           icon=folium.DivIcon(html=f"""
            <div><svg>
                <circle cx="25" cy="25" r="20" fill="#69b3a2" opacity=".4"/>
                <rect x="20", y="20" width="10" height="10", fill="white", opacity=".5" 
            </svg></div>""")
    ).add_to(map_), axis=1)
## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1a5fb67ae902494e9a330ff1ec12b11e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1a5fb67ae902494e9a330ff1ec12b11e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1a5fb67ae902494e9a330ff1ec12b11e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1a5fb67ae902494e9a330ff1ec12b11e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B23.227933%2C%2077.403255%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## For Lodging Venues

# %%
x, y = "lat", "long"
color = "cluster"
popup = "name"
marker = "centroids"
location = [23.240543, 77.387223]
data = Vl2.copy()
## create color column
lst_elements = sorted(list(Vl2[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in 
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x: 
                lst_colors[lst_elements.index(x)])

## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=13)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]], 
           color=row["color"], fill=True,popup=row[popup]).add_to(map_), axis=1)

## add centroids marker
lst_elements = sorted(list(Vl2[marker].unique()))
data[data[marker]==1].apply(lambda row: 
           folium.Marker(location=[row[x],row[y]], 
           draggable=False,  popup=row[popup] ,       
           icon=folium.DivIcon(html=f"""
            <div><svg>
                <circle cx="25" cy="25" r="20" fill="#69b3a2" opacity=".4"/>
                <rect x="20", y="20" width="10" height="10", fill="white", opacity=".5" 
            </svg></div>""")
    ).add_to(map_), axis=1)
## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_82d1e364c20f4009900273bb2d15e2d6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_82d1e364c20f4009900273bb2d15e2d6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_82d1e364c20f4009900273bb2d15e2d6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_82d1e364c20f4009900273bb2d15e2d6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B23.240543%2C%2077.387223%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
